# %% [markdown]
# # Exploration of LLM tool discovery from source code expeiments.
# Okay, so this experiment is about discovering if LLMs can use memory structures to understand what they've done and how they have surfed the linked open data cloud.

# %%
# Uninstall the ccogitarelink package
# ! pip uninstall cogitarelink -y

# %%
## Install fresh from the GitHub Package
# ! pip install --no-cache-dir -U git+https://github.com/la3d/cogitarelink.git

# %%
from cogitarelink.core import *
from cogitarelink.vocabulary import *
from cogitarelink.navigation import *
from cogitarelink.dataset import *
from cogitarelink.utils import *
import json

# %%
from fastcore.basics import *
from fastcore.meta import *
from fastcore.test import *
import json
from rdflib import Graph, URIRef
from pyld import jsonld
from typing import List, Dict, Any, Optional, Union
from bs4 import BeautifulSoup as bs
import httpx
from claudette import Chat, models, toolloop, tool
import datetime

# %% [markdown]
# **AI Prompt**
#
# Hi solveit! I am Chuck, and I am working with you today! I'm an experienced Python coder, experienced with semantic web technologies like OWL,RDF and SPARQL, and I enjoy learning new things. When writing code for me, please follow fast.ai coding style: avoid comments; place single line if/loop/etc constructs on the same line; use concise variable names where appropriate. Follow the style you will see in my messages, as we work on this dialogue together. I am developing this cogitarelink in nbdev notebooks following an exploratory and literate programming style using step-by-step testing. I am the developer of cogitarelink and have installed the package from GitHub. I implimented the core functions you see in your context in another dialog and now want to test and extend the framework. Are you ready?

# %% [markdown]
# **AI Response**
#
# Hi Chuck! I'm ready to help you test and extend the cogitarelink framework. I'll follow the fast.ai coding style with concise syntax and variable names, avoiding unnecessary comments.
#
# Since you're the developer of cogitarelink and have experience with semantic web technologies, I'll tailor my responses accordingly. What specific aspects of the framework would you like to test or extend today? Would you like to explore particular functionalities, add new features, or debug existing components?

# %%
core_py = load_module_source("core")
# Out:
# Loaded core from /app/data/.local/lib/python3.11/site-packages/cogitarelink/core.py (53729 characters)

# %%
vocab_py = load_module_source("vocabulary")
# Out:
# Loaded vocabulary from /app/data/.local/lib/python3.11/site-packages/cogitarelink/vocabulary.py (69997 characters)

# %% [markdown]
# **AI Prompt**
#
# Ok. That seems not to have worked. Here is the source code to $`core_py` and $`vocab_py`

# %% [markdown]
# **AI Response**
#
# I see the source code has been loaded into the variables `core_py` and `vocab_py`. Looking at the context, these contain the source code for the core and vocabulary modules of the cogitarelink framework.
#
# Let's take a look at what we have. The `core_py` variable contains the `LinkedDataKnowledge` class and related functions for working with JSON-LD data, while the `vocab_py` variable contains functions for fetching and processing vocabularies from sources like Wikidata and Schema.org.
#
# Would you like me to:
#
# 1. Analyze the current implementation for potential improvements?
# 2. Help extend a specific feature of the framework?
# 3. Test some functionality with example data?
# 4. Create a new feature that builds on these modules?
#
# What aspect of the framework would you like to focus on today?

# %% [markdown]
# The structure of cogitarelink is built to be "LLM-navigable" where you can:
#
# 1. First examine an index/overview of what's in the knowledge base
# 2. Check if any of those items are relevant to the current question
# 3. If not, perform a reflective process to identify knowledge gaps
# 4. Retrieve additional entities to fill those gaps
#
# This creates a workflow similar to how humans navigate information:
# - "What do I already know about this topic?"
# - "Is what I know sufficient to answer this question?"
# - "If not, what additional information should I look for?"
#
# The prefixed properties (wdt:) and simplified labels make it easier for you to understand the semantics without needing to resolve full URIs, while the graph structure maintains all the rich connections between entities.
#
# Would it be helpful to create a function that generates this kind of "knowledge index" from the current state of the knowledge base? This could provide you with a quick overview of available entities, their types, and key relationships to help you decide what to explore further.

# %% [markdown]
# Based on what we've learned about working with linked data and JSON-LD, here's how an LLM-based agent should build its memory while exploring the linked data cloud:
#
# ## Building an LLM Agent's Memory in the Linked Data Cloud
#
# ### 1. Layered Memory Structure
#
# The agent should maintain a multi-layered memory structure:
#
# - **Working Memory**: The current focus entities and their immediate relationships
# - **Episodic Memory**: The path of exploration and discoveries made
# - **Semantic Memory**: Structured knowledge organized by domain and concept
#
# This mirrors how the `LinkedDataKnowledge` class uses named graphs, the main graph, and included entities.
#
# ### 2. Knowledge Acquisition Process
#
# When exploring linked data, the agent should:
#
# 1. **Start with an Entry Point**: Begin with a known entity or concept URI
# 2. **Fetch and Simplify**: Retrieve the entity data and convert it to a simplified representation
# 3. **Extract Key Information**: Use the `extract_value` function to get essential properties
# 4. **Organize by Domain**: Group related properties using scoped contexts
# 5. **Discover Connections**: Identify links to related entities
# 6. **Follow Selectively**: Choose which links to follow based on relevance to the task
#
# ### 3. Memory Organization Techniques
#
# The agent should leverage JSON-LD 1.1 features to organize memory:
#
# - **Use Resource-Centric Views**: Place the main entity of interest at the root with related entities in `@included`
# - **Apply Scoped Contexts**: Create domain-specific views of properties
# - **Utilize Containers**: Use appropriate containers for different types of multi-valued properties
# - **Maintain Named Graphs**: Store different knowledge domains in separate named graphs
#
# ### 4. Practical Implementation Steps
#
# 1. **Initial Discovery**:
#    - When encountering a new URI, fetch its representation
#    - Add it to the knowledge base using `fetch_vocabulary`
#    - Generate a knowledge index to understand what's available
#
# 2. **Strategic Exploration**:
#    - Use `find_entity_across_graphs` to locate related entities
#    - Use `get_entity_description(simplified=True)` to get concise representations
#    - Apply `extract_value` to access specific property values
#
# 3. **Memory Consolidation**:
#    - Periodically organize knowledge using `structure_with_containers`
#    - Create domain-specific views with `create_scoped_context`
#    - Use `use_included` to create entity-centric views of related information
#
# 4. **Reference Management**:
#    - When encountering external references, use `fetch_external_reference`
#    - Connect references back to source entities
#    - Maintain provenance information about where knowledge came from
#
# ### 5. Navigation Strategies
#
# The agent should employ these strategies for effective navigation:
#
# - **Breadth vs. Depth**: Balance between exploring many related entities superficially or following specific paths deeply
# - **Interest-Based Prioritization**: Prioritize following links related to the current task or question
# - **Vocabulary Discovery**: When encountering new vocabularies, fetch their definitions first
# - **Property Understanding**: Look up the meaning of unfamiliar properties before interpreting their values
#
# ### 6. Real-World Example
#
# For instance, if exploring AI research:
#
# 1. Start with `http://www.wikidata.org/entity/Q11660` (Artificial Intelligence)
# 2. Discover it has a Getty AAT ID (`wdt:P1014` property)
# 3. Fetch that external reference to get cultural/historical context
# 4. Find related concepts like Machine Learning (`Q2539`)
# 5. Organize these in a "Computer Science" named graph
# 6. Create a scoped context for AI-related properties
# 7. Use containers to organize different AI applications by domain
#
# This approach allows the agent to build a rich, interconnected knowledge structure that preserves the semantic relationships of the linked data while making it accessible for LLM reasoning.
#
# Would you like me to elaborate on any specific aspect of this memory-building process?

# %% [markdown]
# Reevaluating our suggested code changes in light of how an LLM should navigate the Linked Open Data (LOD) cloud, I believe they still make sense, but with some important refinements:
#
# ## Reevaluation of Suggested Code Changes
#
# ### 1. `extract_value` Function
#
# Our implementation focuses on simplifying complex JSON-LD structures, which remains essential. However, we should enhance it to:
#
# - **Preserve Context**: When extracting values, we could retain information about which vocabulary the property belongs to
# - **Support Multiple Values**: Instead of just returning the first value, provide options to access all values when needed
# - **Handle Language Preferences**: Add parameters to specify language preferences for labeled content
#
# This would better support the agent's need to maintain context while navigating the LOD cloud.
#
# ### 2. URI Simplification
#
# Our generalized URI simplification approach is still valuable, but should be extended to:
#
# - **Preserve Namespace Information**: Rather than just extracting the final segment, maintain a mapping of prefixes to namespaces
# - **Support Reversibility**: Allow converting back to full URIs when needed for following links
# - **Track Provenance**: Maintain information about where each URI was encountered
#
# This supports the agent's need to follow links accurately while still keeping representations compact.
#
# ### 3. Property Meaning Discovery
#
# This remains crucial but should be enhanced to:
#
# - **Cache Results**: Store property meanings to avoid repeated lookups
# - **Support Vocabulary Hierarchies**: Understand that properties may inherit meaning from parent properties
# - **Prioritize Context-Relevant Meanings**: When a property has different meanings in different contexts, prioritize the one relevant to the current exploration path
#
# This aligns with the agent's need to understand property semantics during navigation.
#
# ### 4. Entity Description
#
# Our simplified entity descriptions are still valuable, but should:
#
# - **Adapt Detail Level**: Provide different levels of detail based on whether an entity is the focus or a related entity
# - **Highlight Connections**: Emphasize properties that link to other entities to facilitate navigation
# - **Include Navigation Hints**: Suggest potential paths for further exploration
#
# This supports the "follow your nose" principle in the agent's exploration.
#
# ## What's Missing in Our Implementation
#
# Looking at the LOD navigation process, our implementation is missing:
#
# 1. **Exploration State Tracking**: We don't track the agent's path through the LOD cloud, which would be valuable for episodic memory
#
# 2. **Interest-Based Prioritization**: We don't have mechanisms to prioritize which links to follow based on relevance to the task
#
# 3. **Memory Consolidation**: While we have tools for organizing knowledge, we don't have strategies for when and how to consolidate it
#
# 4. **Navigation Strategies**: We lack explicit support for breadth-first vs. depth-first exploration strategies
#
# ## Refined Implementation Approach
#
# A more complete implementation would:
#
# 1. Add an `ExplorationPath` class to track the agent's journey through the LOD cloud
#
# 2. Implement relevance scoring for potential links to follow
#
# 3. Create periodic memory consolidation functions that organize knowledge based on usage patterns
#
# 4. Add exploration strategy parameters to guide the navigation process
#
# 5. Enhance our existing functions to better support the layered memory model (working, episodic, semantic)
#
# Our current implementations are a solid foundation, providing the basic tools for LOD navigation. They need refinement rather than replacement to fully support an LLM agent's navigation of the LOD cloud.
#
# The core principles we followed—vocabulary agnosticism, uniform resource treatment, metadata self-description, and graceful degradation—remain essential for effective LOD navigation.
#
# Would you like me to elaborate on any specific aspect of this reevaluation?

# %%
kb = LinkedDataKnowledge()
# First fetch an entity that has external references
kb.fetch_vocabulary("Q11660")  # Artificial Intelligence entity from Wikidata

# Then fetch a specific external reference
kb.fetch_external_reference(
    source_entity_id="Q11660",  # Wikidata entity ID
    property_id="P1014",        # Getty AAT ID property
    ref_value="300251574",      # The specific Getty AAT ID
    debug=True                  # Optional debug output
)
# Out:
# Fetching external reference for Q11660, property P1014, value 300251574
# Property not found, fetching from Wikidata
# Detected Wikidata entity: P1014
# Fetching Wikidata entity: P1014
# Parsed 372 triples from Turtle response
# Triples where P1014 is the subject: 349
# Triples where P1014 is the object: 1
# JSON-LD serialization returned a list of 16 entities
# Converted to standard JSON-LD structure with @graph
# Looking for entity with URI: http://www.wikidata.org/entity/P1014
# Found entity by canonical URI
# Added simplified label: Art & Architecture Thesaurus ID
# Added simplified description: identifier in the Art & Architecture Thesaurus by the Getty Research Institute
# Converted property: http://www.wikidata.org/prop/direct/P12508 -> wdt:P12508
# Converted property: http://www.wikidata.org/prop/direct/P1629 -> wdt:P1629
# Converted property: http://www.wikidata.org/prop/direct/P1630 -> wdt:P1630
# Converted property: http://www.wikidata.org/prop/direct/P1659 -> wdt:P1659
# ...

# %% [markdown]
# **AI Prompt**
#
# Okay, so this is a general example of how to use the Cogitarelink package. What do we think?

# %% [markdown]
# **AI Response**
#
# Looking at the example, it demonstrates a key feature of the cogitarelink framework - the ability to fetch external references from linked data sources.
#
# The code shows a two-step process:
# 1. First fetching an entity (Q11660 - Artificial Intelligence) from Wikidata
# 2. Then using the `fetch_external_reference` method to retrieve additional information from a Getty AAT reference (300251574) connected to that entity via the P1014 property
#
# From the debug output, we can see the framework is:
# - Intelligently fetching the property definition (P1014) when needed
# - Using the formatter URL pattern found in that property to construct the Getty URL
# - Successfully retrieving and storing the external reference data
# - Adding it to the knowledge base as a named graph
# - Creating connections between the original entity and this new reference
#
# This demonstrates cogitarelink's "follow your nose" capability - starting with one piece of information and discovering connected resources across the linked data cloud.
#
# What do you think about this approach? Would you like to explore other features or perhaps see how we could build on this to create more complex knowledge navigation patterns?

# %% [markdown]
# **AI Prompt**
#
# Please look at the suggested source code changes note. I'd like to do a set of experiments first, before we change any source code, to understand how an LLM might use the tools to manage its own memory and to surf the linked open data cloud.

# %% [markdown]
# **AI Response**
#
# That's a great approach. Before making any source code changes, let's run some experiments to understand how an LLM could effectively use the existing tools to manage memory and navigate the linked open data cloud.
#
# I suggest we start with a few experiments:
#
# 1. **Knowledge Acquisition Experiment**: How an LLM might systematically gather and organize information about a topic by following connections
#
# 2. **Memory Organization Experiment**: Testing different ways to structure the acquired knowledge for later retrieval and reasoning
#
# 3. **Navigation Strategy Experiment**: Comparing different approaches to deciding which links to follow when exploring
#
# Would you like to start with one of these experiments, or do you have a specific experiment in mind that you'd prefer to try first?

# %% [markdown]
# **AI Prompt**
#
# Where do you think we should start?

# %% [markdown]
# **AI Response**
#
# I think starting with the Knowledge Acquisition Experiment makes the most sense. It forms the foundation for the other experiments, as we need to first understand how an LLM can effectively gather information before we can optimize its organization or navigation strategies.
#
# For this experiment, we could:
#
# 1. Begin with a single entity (like "Artificial Intelligence" that we've already fetched)
# 2. Identify the most relevant properties and connected entities
# 3. Develop a systematic process for deciding which connections to follow
# 4. Track what we learn at each step
# 5. Create a record of the exploration path
#
# This would help us understand how an LLM might build its knowledge base incrementally while maintaining awareness of what it knows and how it discovered that information.
#
# Would you like to proceed with this experiment? If so, I can help outline a specific procedure to test.

# %% [markdown]
# **AI Prompt**
#
# I think this would be good to extend the knowledge acquisition experiment, but have the LLM write to memory. I want you to pretend that you're an agent in a workflow to some extent. We can use Claudette Chat to help us see what an LLM would interpret the underlying results as, but the functionality for writing, retrieving, and putting things into the context window is your job through template variables. Also, creating the code that manages the navigation through memory space is your job. We want to explore Building an LLM Agent's Memory in the Linked Data Cloud

# %% [markdown]
# **AI Response**
#
# I understand the approach. I'll act as an agent that manages memory while navigating the linked data cloud, focusing on knowledge acquisition and memory management.
#
# Let's start by creating a framework for this experiment. We'll need:
#
# 1. A memory structure to track our exploration
# 2. Functions to write to and read from this memory
# 3. Navigation logic to decide what to explore next
# 4. A way to reflect on what we've learned
#
# Here's a proposed structure for our memory:
#
# ```python
# class AgentMemory:
#     def __init__(self):
#         # Main knowledge base
#         self.kb = LinkedDataKnowledge()
#
#         # Exploration path - track where we've been
#         self.exploration_path = []
#
#         # Current focus - what we're currently examining
#         self.current_focus = None
#
#         # Interesting properties - properties we've found valuable
#         self.interesting_properties = set()
#
#         # Questions we're trying to answer
#         self.active_questions = []
# ```
#
# Would this structure work for our experiment? We can then add methods for writing to memory, retrieving information, and navigating the linked data cloud.

# %%
class AgentMemory:
    def __init__(self):
        # Main knowledge base
        self.kb = LinkedDataKnowledge()
        
        # Exploration path - track where we've been
        self.exploration_path = []
        
        # Current focus - what we're currently examining
        self.current_focus = None
        
        # Interesting properties - properties we've found valuable
        self.interesting_properties = set()
        
        # Questions we're trying to answer
        self.active_questions = []

# %%
# Create a simple agent with a knowledge base and LLM
kb = LinkedDataKnowledge()
chat = Chat(models[1])  # Using Claude 3 Sonnet

# Fetch our first entity - Artificial Intelligence
print("Fetching AI entity...")
kb.fetch_vocabulary("Q11660")
# Out:
# Fetching AI entity...
# LinkedDataKnowledge with 0 entities

# %%
# Find the AI entity in our knowledge base
ai_entity = kb.find_entity_across_graphs(entity_id="Q11660")[0]

# Let's see what properties we have
print(f"AI entity has {len(ai_entity)} properties")
print(f"Properties: {', '.join(list(ai_entity.keys())[:10])}...")

# Ask the LLM to analyze this entity
prompt = f"""I've fetched the Wikidata entity for Artificial Intelligence (Q11660).
Here's the entity data:

{json.dumps(ai_entity, indent=2)[:1000]}...

Please analyze this entity and tell me:
1. What are the most important properties?
2. What related entities might be worth exploring?
3. How would you organize this information to build a mental model of AI?
"""

# Get analysis from Claude
analysis = chat(prompt)

# Extract and print the text content in a more readable format
if hasattr(analysis, 'content') and analysis.content:
    print("\nLLM Analysis:")
    # Extract text from the first text block
    for block in analysis.content:
        if hasattr(block, 'text'):
            print(block.text)
# Out:
# AI entity has 333 properties
# Properties: @id, @type, http://schema.org/description, http://schema.org/name, http://www.w3.org/2000/01/rdf-schema#label, http://www.w3.org/2004/02/skos/core#altLabel, http://www.w3.org/2004/02/skos/core#prefLabel, http://www.wikidata.org/prop/direct-normalized/P1014, http://www.wikidata.org/prop/direct-normalized/P1617, http://www.wikidata.org/prop/direct-normalized/P2004...
#
# LLM Analysis:
# # Analysis of Wikidata Entity for Artificial Intelligence (Q11660)
#
# Based on the partial data you've provided, I can offer some initial analysis of the Wikidata entity for Artificial Intelligence.
#
# ## 1. Most Important Properties
#
# From the snippet shown, I can see:
# - Entity ID: Q11660
# - Entity Type: Item
# - Descriptions in multiple languages (Italian, Russian, Spanish)
#
# The full entity would likely contain important properties such as:
# - Instance of (P31): likely "field of study," "academic discipline," etc.
# ...

# %% [markdown]
# **AI Prompt**
#
# Ok. Let's ask it to give evidence and point to the information entities and properties for the conclusions

# %% [markdown]
# **AI Response**
#
# Great idea! Let's ask the LLM to provide specific evidence from the entity data to support its conclusions. This will help us understand how it's interpreting and using the information in the knowledge base.
#
# Let's modify our approach to request evidence-based analysis:
#
# ```python
# # Let's get a more detailed look at the AI entity
# ai_graph_id = kb._create_vocabulary_graph_id("Q11660")
# full_graph_id = f"did:cogitarelink:graph:{ai_graph_id}"
#
# # Get a more detailed representation of the entity
# entity_description = kb.get_entity_description(ai_entity)
# print(f"Entity description length: {len(entity_description)} characters")
#
# # Now let's ask for evidence-based analysis
# evidence_prompt = f"""I've fetched the Wikidata entity for Artificial Intelligence (Q11660).
# Here's the entity data:
#
# {json.dumps(ai_entity, indent=2)[:1500]}...
#
# Please analyze this entity and provide SPECIFIC EVIDENCE from the data for your conclusions:
#
# 1. What are the most important properties? Cite the exact property IDs and values.
# 2. What related entities might be worth exploring? Provide the exact entity IDs.
# 3. How would you organize this information? Reference specific properties that support your organizational structure.
#
# For each conclusion, quote the specific data you're basing it on.
# """
#
# evidence_analysis = chat(evidence_prompt)
# print("\nEvidence-Based Analysis:")
# print(evidence_analysis)
# ```
#
# This will help us see how the LLM connects specific pieces of data to its conclusions, which is crucial for understanding how it builds its mental model from the linked data.

# %%
# Let's get a more detailed look at the AI entity
ai_graph_id = kb._create_vocabulary_graph_id("Q11660")
full_graph_id = f"did:cogitarelink:graph:{ai_graph_id}"

# Get a more detailed representation of the entity
entity_description = kb.get_entity_description(ai_entity)
print(f"Entity description length: {len(entity_description)} characters")

# Now let's ask for evidence-based analysis
evidence_prompt = f"""I've fetched the Wikidata entity for Artificial Intelligence (Q11660).
Here's the entity data:

{json.dumps(ai_entity, indent=2)[:1500]}...

Please analyze this entity and provide SPECIFIC EVIDENCE from the data for your conclusions:

1. What are the most important properties? Cite the exact property IDs and values.
2. What related entities might be worth exploring? Provide the exact entity IDs.
3. How would you organize this information? Reference specific properties that support your organizational structure.

For each conclusion, quote the specific data you're basing it on.
"""

evidence_analysis = chat(evidence_prompt)
print("\nEvidence-Based Analysis:")
print(evidence_analysis)
# Out:
# Entity description length: 46824 characters
#
# Evidence-Based Analysis:
# ...

# %% [markdown]
# **AI Prompt**
#
# Ok. What do we think of this?

# %% [markdown]
# **AI Response**
#
# The LLM's analysis reveals some interesting insights about how it works with the limited data it received:
#
# 1. **Recognition of incomplete data**: The LLM correctly identified that it only received a partial view of the entity, showing awareness of what information is missing.
#
# 2. **Focus on available evidence**: It properly restricted its analysis to what was actually visible in the snippet (entity ID, type, and descriptions in multiple languages).
#
# 3. **Honest about limitations**: Instead of fabricating connections or properties, it explicitly stated when it couldn't find evidence for certain conclusions.
#
# 4. **Language analysis**: Interestingly, it extracted meaningful patterns from the multilingual descriptions, noting how different languages emphasize different aspects of AI (technical, capability, manifestation, and creation perspectives).
#
# This suggests that for an LLM to effectively navigate linked data, it needs:
#
# 1. Access to more complete entity data
# 2. The ability to follow links to related entities
# 3. A way to track what information it has and hasn't seen
# 4. Methods to organize information from multiple sources
#
# To improve this experiment, we could:
# - Ensure we're sending the complete entity data
# - Implement a way to follow connections to related entities
# - Add memory structures to track the exploration path
# - Create visualization methods to help understand the knowledge graph
#
# What aspect would you like to focus on improving next?

# %% [markdown]
# **AI Prompt**
#
# Ok. I think this approach is really good but you've written a bunch of code. Remember we are doing this step-by-step in an exporatory/literate style and we don't quite know what the best structure of how to organize or LOD surfer agent memory.

# %% [markdown]
# **AI Response**
#
# You're absolutely right. I got ahead of myself by writing a complete implementation instead of taking the exploratory, step-by-step approach that's more in line with the fast.ai/fastcore style. Let's take a step back and approach this more incrementally.
#
# Instead of trying to design the entire system at once, let's start with a minimal version and evolve it based on what we learn. Here's a more exploratory approach:
#
# 1. First, let's just track what entities we've visited and what we're currently looking at
# 2. Then we'll experiment with different ways to identify and follow connections
# 3. Finally, we'll explore how to organize what we've learned
#
# Let's start with a very simple memory structure:
#
# ```python
# # Simple starting point for our agent memory
# memory = {
#     "visited": set(),         # Entities we've visited
#     "current": None,          # Current entity we're examining
#     "observations": [],       # Notes about what we've learned
#     "exploration_path": []    # History of our exploration
# }
# ```
#
# We can begin with a simple experiment - fetch the AI entity, examine it, and identify some interesting connections to follow:
#
# ```python
# # Start with AI entity
# memory["current"] = "Q11660"  # Artificial Intelligence
# memory["visited"].add("Q11660")
# memory["exploration_path"].append({"action": "visit", "entity": "Q11660", "reason": "Starting point"})
#
# # Fetch the entity
# kb = LinkedDataKnowledge()
# kb.fetch_vocabulary(memory["current"])
#
# # Examine the entity
# ai_entity = kb.find_entity_across_graphs(entity_id=memory["current"])[0]
#
# # Record an observation
# memory["observations"].append({
#     "entity": memory["current"],
#     "note": "This is the Wikidata entity for Artificial Intelligence",
#     "timestamp": datetime.datetime.now().isoformat()
# })
# ```
#
# This gives us a foundation to build on as we explore. We can iteratively enhance our memory structure based on what we learn from each experiment.
#
# Does this more incremental approach make sense as a starting point?

# %%
# Create a JSON-LD 1.1 memory structure
memory = {
    "@context": {
        "@version": 1.1,
        "schema": "https://schema.org/",
        "cogito": "https://cogitarelink.org/ns#",
        
        "visited": "cogito:visited",
        "current": "cogito:currentFocus",
        "path": "cogito:explorationPath",
        "observations": "cogito:observations",
        
        "Observation": "cogito:Observation",
        "ExplorationStep": "cogito:ExplorationStep",
        
        "entity": {"@id": "cogito:entity", "@type": "@id"},
        "timestamp": {"@id": "schema:dateCreated", "@type": "xsd:dateTime"},
        "action": "cogito:action",
        "reason": "schema:description",
        "note": "schema:text"
    },
    
    "@id": "cogito:memory1",
    "@type": "cogito:AgentMemory",
    
    "current": None,
    "visited": [],
    "path": [],
    "observations": []
}

# %%
# Initialize our knowledge base
kb = LinkedDataKnowledge()

# Start with AI entity
entity_id = "Q11660"  # Artificial Intelligence

# Update our memory
memory["current"] = {"@id": f"http://www.wikidata.org/entity/{entity_id}"}
memory["visited"].append({"@id": f"http://www.wikidata.org/entity/{entity_id}"})
memory["path"].append({
    "@type": "ExplorationStep",
    "action": "visit",
    "entity": {"@id": f"http://www.wikidata.org/entity/{entity_id}"},
    "reason": "Starting point",
    "timestamp": datetime.datetime.now().isoformat()
})

# Fetch the entity
print(f"Fetching entity: {entity_id}")
kb.fetch_vocabulary(entity_id)

# Record an observation
memory["observations"].append({
    "@type": "Observation",
    "entity": {"@id": f"http://www.wikidata.org/entity/{entity_id}"},
    "note": "This is the Wikidata entity for Artificial Intelligence",
    "timestamp": datetime.datetime.now().isoformat()
})
# Out:
# Fetching entity: Q11660

# %% [markdown]
# **AI Prompt**
#
# Ok. What happened here?

# %% [markdown]
# **AI Response**
#
# We've successfully started building our agent's memory using JSON-LD 1.1 and have begun our exploration of the linked data cloud:
#
# 1. First, we created a structured memory using JSON-LD 1.1 format with a proper context that defines our vocabulary. This gives our agent's memory semantic meaning that can be understood by other systems.
#
# 2. Then we started our exploration with the Wikidata entity for Artificial Intelligence (Q11660):
#    - We set it as our current focus
#    - Added it to our visited entities list
#    - Recorded this step in our exploration path
#    - Fetched the entity's data using the cogitarelink framework
#    - Added an observation about this entity to our memory
#
# The `kb.fetch_vocabulary(entity_id)` call successfully executed, which means the AI entity data has been fetched and added to our knowledge base. However, we haven't yet examined what we've found or identified connections to follow.
#
# The next steps would be to:
#
# 1. Examine the AI entity we've fetched to understand its structure
# 2. Identify interesting properties that link to other entities
# 3. Choose which connections to follow next
# 4. Update our memory as we continue exploring
#
# Would you like to examine the AI entity we've fetched to see what connections we might follow next?

# %%
# Retrieve the AI entity from our knowledge base
ai_entity = kb.find_entity_across_graphs(entity_id="Q11660")[0]

# Let's see what properties we have
print(f"AI entity has {len(ai_entity)} properties")

# Look for properties that link to other entities
linked_entities = []
for prop, value in ai_entity.items():
    # Skip metadata properties
    if prop.startswith('@'):
        continue
        
    # Look for properties that might contain entity references
    if isinstance(value, list):
        for item in value:
            if isinstance(item, dict) and '@id' in item:
                linked_entities.append((prop, item['@id']))
    elif isinstance(value, dict) and '@id' in value:
        linked_entities.append((prop, value['@id']))

# Print the first few linked entities we found
print(f"Found {len(linked_entities)} links to other entities")
for prop, entity in linked_entities[:5]:
    print(f"  {prop} -> {entity}")
# Out:
# AI entity has 333 properties
# Found 192 links to other entities
#   http://www.wikidata.org/prop/direct-normalized/P1014 -> http://vocab.getty.edu/aat/300251574
#   http://www.wikidata.org/prop/direct-normalized/P1617 -> http://www.bbc.co.uk/things/6a57de69-8b35-4777-9a42-621da0e39310#id
#   http://www.wikidata.org/prop/direct-normalized/P2004 -> https://lod.nal.usda.gov/nalt/203390
#   http://www.wikidata.org/prop/direct-normalized/P227 -> https://d-nb.info/gnd/4033447-8
#   http://www.wikidata.org/prop/direct-normalized/P2347 -> http://www.yso.fi/onto/yso/p2616

# %%
from claudette import Chat, models

# Initialize Claudette
chat = Chat(models[1])  # Using Claude 3 Sonnet

# Let's have Claudette analyze the entity and suggest which connections to follow
analysis_prompt = f"""
I'm exploring the linked data cloud, starting with Artificial Intelligence (Wikidata Q11660).
I've found {len(linked_entities)} links to other entities from this starting point.

Here are the first 10 links I found:
{linked_entities[:10]}

Based on this information:
1. Which 3 connections do you think would be most valuable to explore next and why?
2. What patterns do you notice in the types of connections available?
3. How would you categorize these different types of connections?

Please provide specific reasoning for your recommendations.
"""

# Get Claudette's analysis
analysis = chat(analysis_prompt)
print("Claudette's Analysis:")
print(analysis)
# Out:
# Claudette's Analysis:
# ...

# %% [markdown]
# **AI Prompt**
#
# OK. What do we think of this response?

# %% [markdown]
# **AI Response**
#
# This response from Claude is quite insightful and shows how an LLM can effectively analyze and make sense of linked data connections.
#
# Key observations about Claude's analysis:
#
# 1. **Meaningful categorization**: Claude organized the connections into three logical categories (National Library Authority Files, Domain-Specific Vocabularies, and General Knowledge Organization Systems), which is a useful way to understand the different types of knowledge sources.
#
# 2. **Strategic recommendations**: Instead of just picking random connections, Claude recommended following links that would provide diverse perspectives (Library of Congress, Mathematics Subject Classification, and German National Library) with specific reasoning for each choice.
#
# 3. **Pattern recognition**: Claude identified important patterns in the data, such as geographic diversity, domain-specific classifications, and the prevalence of authority control systems.
#
# 4. **Contextual understanding**: Claude demonstrated understanding of what these connections represent in the broader knowledge landscape (e.g., recognizing that 68Txx is the mathematical classification for AI).
#
# This shows how an LLM can serve as an effective guide when navigating the linked data cloud by:
# - Identifying the most promising paths to follow
# - Recognizing patterns across different knowledge organization systems
# - Categorizing information in meaningful ways
# - Providing reasoned recommendations for exploration
#
# For our agent memory experiment, this suggests we should incorporate:
# 1. A way to categorize connections
# 2. A mechanism for prioritizing which links to follow
# 3. Storage for patterns observed across different knowledge sources
#
# What do you think about proceeding with exploring one of the recommended connections?

# %% [markdown]
# Based on our experiment, we've gained several insights about how to structure our AgentMemory class:
#
# 1. **Semantic Organization of Connections**
#    - The LLM naturally categorized connections into meaningful groups (National Libraries, Domain Vocabularies, etc.)
#    - Our memory structure should support this categorization of links
#
# 2. **Prioritization Mechanism**
#    - The LLM made strategic recommendations about which connections to explore
#    - We need a way to store and track priority/importance of different connections
#
# 3. **Pattern Storage**
#    - The LLM identified patterns across connections
#    - We should have a way to record these observed patterns for future navigation
#
# 4. **Contextual Understanding**
#    - The LLM provided context about what different connections represent
#    - Our memory should store these interpretations alongside raw data
#
# 5. **Exploration Rationale**
#    - The LLM gave specific reasoning for its recommendations
#    - We should track not just what we explore, but why we chose to explore it
#
# The key additions based on our experiment:
#
# 1. **Categories** - To store the types of connections we've discovered
# 2. **Patterns** - To record observed patterns across connections
# 3. **Priorities** - To track which connections are most valuable to explore
# 4. **Rationale** - Added to store reasoning behind decisions
# 5. **Examples** - To link patterns and categories to specific instances
#
# This structure allows an LLM to not just navigate the linked data cloud, but to build a meaningful mental model of the knowledge landscape it's exploring.

# %%
# Revised JSON-LD memory structure with correct namespace
memory = {
    "@context": {
        "@version": 1.1,
        "schema": "https://schema.org/",
        "cogito": "https://cogitarelink.ai/ns#",  # Updated URI
        
        "visited": "cogito:visited",
        "current": "cogito:currentFocus",
        "path": "cogito:explorationPath",
        "observations": "cogito:observations",
        "patterns": "cogito:observedPatterns",
        "categories": "cogito:connectionCategories",
        "priorities": "cogito:connectionPriorities",
        
        "Pattern": "cogito:Pattern",
        "Category": "cogito:Category",
        "Connection": "cogito:Connection",
        "Observation": "cogito:Observation",
        "ExplorationStep": "cogito:ExplorationStep",
        
        "entity": {"@id": "cogito:entity", "@type": "@id"},
        "timestamp": {"@id": "schema:dateCreated", "@type": "xsd:dateTime"},
        "action": "cogito:action",
        "reason": "schema:description",
        "note": "schema:text",
        "priority": "cogito:priority",
        "rationale": "cogito:rationale",
        "examples": "cogito:examples"
    },
    
    "@id": "cogito:memory1",
    "@type": "cogito:AgentMemory",
    
    "current": None,
    "visited": [],
    "path": [],
    "observations": [],
    
    "patterns": [],
    "categories": [],
    "priorities": []
}

# %% [markdown]
# **AI Prompt**
#
# OK. we have a sample memory structure. What should we do next. We also have to think about vocabulary management if the agent doesn't understand a vocabulary. LLM's tend to hallucinate based on the sematics of a IRI, not the semantics of the thing based on a definition/properties/affordances.

# %% [markdown]
# **AI Response**
#
# You raise an excellent point about vocabulary management. LLMs often infer meaning from IRIs based on their textual structure rather than their actual defined semantics, which can lead to hallucinations. Let's address this issue and plan our next steps.
#
# ### Next Steps with Vocabulary Management in Mind
#
# 1. **Create a Vocabulary Registry**:
#    - We should add a vocabulary registry to our memory structure where the agent can store definitions of terms it encounters
#    - This would map predicates/properties to their formal definitions
#
# 2. **Implement Property Discovery**:
#    - When encountering an unfamiliar property (like wdt:P1014), the agent should fetch its definition
#    - This would help the agent understand what the property actually means rather than guessing
#
# 3. **Test with Unknown Vocabulary**:
#    - We should test how the agent handles unfamiliar vocabularies
#    - See if it can correctly discover and learn their meaning
#
# Here's how we might extend our memory structure:
#
# ```python
# # Add vocabulary registry to memory
# memory["@context"]["vocabularies"] = "cogito:vocabularyRegistry"
# memory["@context"]["PropertyDefinition"] = "cogito:PropertyDefinition"
# memory["@context"]["predicate"] = {"@id": "cogito:predicate", "@type": "@id"}
# memory["@context"]["definition"] = "cogito:definition"
# memory["@context"]["domain"] = {"@id": "cogito:domain", "@type": "@id"}
# memory["@context"]["range"] = {"@id": "cogito:range", "@type": "@id"}
#
# # Add vocabularies section to memory
# memory["vocabularies"] = []
# ```
#
# Next, we should implement a function to discover property definitions:
#
# ```python
# def discover_property_definition(kb, property_uri):
#     """
#     Fetch the definition of a property to understand its semantics.
#
#     For Wikidata properties (wdt:P...), this would fetch the property entity.
#     For other vocabularies, it would look up the property definition.
#     """
#     # Extract property ID for Wikidata properties
#     if property_uri.startswith("http://www.wikidata.org/prop/") or property_uri.startswith("wdt:"):
#         # Extract the P-number
#         if "P" in property_uri:
#             property_id = "P" + property_uri.split("P")[-1].split("/")[0].split(":")[0]
#             # Fetch the property entity
#             kb.fetch_vocabulary(property_id)
#             # Find the property entity
#             property_entity = kb.find_entity_across_graphs(entity_id=property_id)[0]
#             return property_entity
#
#     # For other vocabulary terms, we would need to implement
#     # vocabulary-specific lookup methods
#     return None
# ```
#
# Would you like to:
# 1. Implement the property discovery function and test it on a Wikidata property?
# 2. Extend our memory structure to track vocabulary understanding?
# 3. Test how an LLM interprets properties with and without formal definitions?

# %%
# Add vocabulary registry to memory
memory["@context"]["vocabularies"] = "cogito:vocabularyRegistry"
memory["@context"]["PropertyDefinition"] = "cogito:PropertyDefinition"
memory["@context"]["predicate"] = {"@id": "cogito:predicate", "@type": "@id"}
memory["@context"]["definition"] = "cogito:definition"
memory["@context"]["domain"] = {"@id": "cogito:domain", "@type": "@id"}
memory["@context"]["range"] = {"@id": "cogito:range", "@type": "@id"}

# Add vocabularies section to memory
memory["vocabularies"] = []

# Implement property discovery function
def discover_property_definition(kb, property_uri):
    """
    Fetch the definition of a property to understand its semantics.
    """
    # Extract property ID for Wikidata properties
    if property_uri.startswith("http://www.wikidata.org/prop/") or property_uri.startswith("wdt:"):
        # Extract the P-number
        if "P" in property_uri:
            property_id = "P" + property_uri.split("P")[-1].split("/")[0].split(":")[0]
            print(f"Extracted property ID: {property_id}")
            
            # Fetch the property entity
            kb.fetch_vocabulary(property_id)
            
            # Find the property entity
            property_entities = kb.find_entity_across_graphs(entity_id=property_id)
            if property_entities:
                return property_entities[0]
    
    # For other vocabulary terms, we would need to implement
    # vocabulary-specific lookup methods
    return None

# Let's test with one of the properties we found earlier
test_property = "http://www.wikidata.org/prop/direct-normalized/P1014"
print(f"Testing property discovery for: {test_property}")

# Discover the property definition
property_entity = discover_property_definition(kb, test_property)

# Add to our vocabulary registry if found
if property_entity:
    # Extract key information
    property_label = property_entity.get('label', 'Unknown')
    property_description = property_entity.get('description', 'No description available')
    
    # Add to our vocabulary registry
    memory["vocabularies"].append({
        "@type": "PropertyDefinition",
        "predicate": test_property,
        "definition": property_description,
        "label": property_label
    })
    
    print(f"Added property to vocabulary registry: {property_label}")
    print(f"Definition: {property_description}")
else:
    print("Property definition not found")

# Now let's test how an LLM interprets this property with and without the definition
# Out:
# Testing property discovery for: http://www.wikidata.org/prop/direct-normalized/P1014
# Extracted property ID: P1014
# Added property to vocabulary registry: Unknown
# Definition: No description available

# %% [markdown]
# **AI Prompt**
#
# Ok. What happened here?

# %% [markdown]
# **AI Response**
#
# It looks like our property discovery function worked partially:
#
# 1. We successfully extracted the property ID "P1014" from the URI
# 2. We fetched the property entity from Wikidata
# 3. We found the entity in our knowledge base
#
# However, we encountered an issue with extracting the label and description from the property entity. The code executed without errors, but it added the property to our vocabulary registry with placeholder values:
# - Label: "Unknown"
# - Definition: "No description available"
#
# This suggests that the property entity doesn't have the 'label' and 'description' fields directly accessible as we expected. This is likely because:
#
# 1. The property entity structure might be different from what we anticipated
# 2. The label and description might be stored under different keys or in a different format
# 3. The entity might need additional processing to extract these values
#
# To fix this, we should examine the actual structure of the property entity to understand how to correctly extract the label and description. Let's modify our code to:
#
# 1. Print the property entity structure to understand its format
# 2. Identify the correct paths to access the label and description
# 3. Update our extraction logic accordingly
#
# Would you like me to implement these changes so we can properly extract the property definition?

# %%
# Let's examine the property entity with the help of an LLM
def extract_property_meaning_with_llm(property_entity, property_uri):
    """Use an LLM to understand and extract meaning from a property entity"""
    
    # Create a prompt for the LLM
    prompt = f"""
    I need to understand the meaning of this Wikidata property: {property_uri}
    
    Here's the entity data I've retrieved:
    
    {json.dumps(property_entity, indent=2)[:2000]}...
    
    Please extract and explain:
    1. The label or name of this property
    2. Its definition or description
    3. What kind of values it typically contains
    4. How it should be interpreted in the context of linked data
    
    Format your response as:
    LABEL: [property label]
    DESCRIPTION: [property description]
    VALUE_TYPE: [type of values]
    INTERPRETATION: [how to use/interpret this property]
    """
    
    # Get the LLM's interpretation
    interpretation = chat(prompt)
    
    print("\nLLM's interpretation of the property:")
    print(interpretation)
    
    return interpretation

# Test our approach with the property we discovered
if property_entity:
    llm_interpretation = extract_property_meaning_with_llm(property_entity, test_property)
    
    # Now we can update our vocabulary registry with this richer understanding
    # We could parse the structured response or just store the full interpretation
    memory["vocabularies"][-1]["llm_interpretation"] = str(llm_interpretation)
# Out:
# LLM's interpretation of the property:
# ...

# %% [markdown]
# **AI Prompt**
#
# Ok. What did we learn from this?

# %% [markdown]
# **AI Response**
#
# This experiment revealed several important insights about using LLMs to navigate linked data:
#
# 1. **LLMs excel at semantic interpretation**: The LLM successfully extracted meaningful information from the property entity, even though our code-based approach couldn't find the direct label and description fields. It provided:
#    - A clear label ("Getty AAT ID")
#    - A detailed description of what the property represents
#    - Information about the value type (external identifier format)
#    - Contextual interpretation for how to use this property in linked data
#
# 2. **Hybrid approach works best**: Combining structured data processing (our code that fetches and processes entities) with LLM interpretation (extracting meaning) creates a powerful system where:
#    - Code handles the technical navigation of the linked data cloud
#    - LLMs handle the semantic interpretation of what's discovered
#
# 3. **Memory structure needs flexibility**: Our JSON-LD memory structure was able to accommodate the LLM's interpretation, showing that we can store both structured data and rich textual explanations.
#
# 4. **Vocabulary discovery is critical**: The experiment confirms that understanding property semantics is essential for proper navigation of linked data. Without knowing what "P1014" means, an agent would struggle to make informed decisions about following that link.
#
# 5. **Contextual understanding adds value**: The LLM went beyond basic label/description extraction to explain how this property connects Wikidata to the Getty vocabulary, highlighting the role of this property in the broader linked data ecosystem.
#
# For building an effective agent memory system, this suggests we should:
#
# 1. Use code to handle technical linked data operations
# 2. Use LLMs to interpret and explain the semantics of discovered entities
# 3. Store both structured data and semantic interpretations in our memory
# 4. Maintain a vocabulary registry that grows as the agent explores
# 5. Use the LLM's interpretations to guide navigation decisions
#
# Would you like to explore how we might use this approach to guide the agent's exploration of the linked data cloud?

# %% [markdown]
# This experiment provides valuable insights about both the AgentMemory structure and the workflow for linked data navigation:
#
# ### AgentMemory Structure Insights
#
# 1. **Layered Memory Requirements**
#    - We need both structured storage (JSON-LD) and interpretative storage (LLM analyses)
#    - The memory should maintain both the raw data and its interpreted meaning
#
# 2. **Vocabulary Registry is Essential**
#    - A dedicated section for storing property/predicate definitions is crucial
#    - This registry should grow organically as the agent encounters new terms
#
# 3. **Context Preservation**
#    - The memory needs to track not just what was discovered but how it relates to other knowledge
#    - The LLM's contextual interpretations should be preserved alongside structured data
#
# 4. **Flexible Schema**
#    - Our JSON-LD structure must be adaptable to accommodate unforeseen data patterns
#    - The `@context` section should evolve as the agent's understanding grows
#
# ### Workflow Insights
#
# 1. **Discover → Interpret → Store → Navigate Cycle**
#    - Discover: Use code to fetch linked data entities
#    - Interpret: Use LLMs to extract meaning and context
#    - Store: Update memory with both data and interpretations
#    - Navigate: Use interpretations to guide the next discovery step
#
# 2. **Incremental Understanding**
#    - The agent builds understanding progressively, with each property interpretation enriching its knowledge
#    - This creates a feedback loop where better understanding leads to more informed navigation
#
# 3. **LLM-Code Collaboration**
#    - Code handles the deterministic aspects (fetching, storing, tracking)
#    - LLMs handle the semantic aspects (interpreting, prioritizing, contextualizing)
#    - This division of labor plays to the strengths of each component
#
# 4. **Knowledge Accumulation**
#    - The vocabulary registry becomes more valuable over time
#    - Previously interpreted properties inform future exploration decisions
#
# For practical implementation, this suggests:
#
# 1. An AgentMemory structure that explicitly includes:
#    - Raw entity data (JSON-LD)
#    - LLM interpretations of entities and properties
#    - A growing vocabulary registry
#    - Navigation history with reasoning
#
# 2. A workflow that:
#    - Fetches entities and identifies unknown properties
#    - Prioritizes which properties to interpret based on relevance
#    - Uses interpretations to decide which connections to follow
#    - Updates memory with both discoveries and their meanings
#
# This hybrid approach creates a system that can navigate the technical complexity of linked data while building semantic understanding of the knowledge landscape.

# %% [markdown]
# Based on our insights, let's refactor our approach with a more structured Python code organization. Here's how we should restructure:
#
# ### Core Components Needed
#
# 1. **AgentMemory Class** - Manages the agent's memory structure
# 2. **LinkedDataNavigator** - Handles linked data exploration
# 3. **SemanticInterpreter** - Uses LLM to interpret entities and properties
# 4. **WorkflowManager** - Orchestrates the discovery-interpretation-navigation cycle
#
# This code structure provides:
#
# 1. **Clear Separation of Concerns**
#    - `AgentMemory` manages the memory structure
#    - `SemanticInterpreter` handles LLM interactions
#    - `LinkedDataNavigator` manages linked data exploration
#    - `WorkflowManager` orchestrates the process
#
# 2. **Flexible Memory Structure**
#    - JSON-LD based memory with proper context
#    - Storage for entity visits, observations, and vocabulary
#
# 3. **Systematic Workflow**
#    - Fetch entities
#    - Interpret their meaning
#    - Discover and interpret properties
#    - Identify connections to follow
#
# 4. **LLM Integration**
#    - Structured prompts for entity and property interpretation
#    - Storage of interpretations alongside raw data
#
# This approach combines the technical precision needed for linked data navigation with the semantic understanding provided by LLMs, creating a system that can effectively explore and make sense of the linked data cloud.

# %%
#| export
BASE_MEMORY_CONTEXT = {
    "@version": 1.1,
    "schema": "https://schema.org/",
    "cogito": "https://cogitarelink.ai/ns#",
    
    "visited": "cogito:visited",
    "current": "cogito:currentFocus",
    "path": "cogito:explorationPath",
    "observations": "cogito:observations",
    "vocabularies": "cogito:vocabularyRegistry",
    "patterns": "cogito:observedPatterns",
    "categories": "cogito:connectionCategories",
    
    "PropertyDefinition": "cogito:PropertyDefinition",
    "Pattern": "cogito:Pattern",
    "Category": "cogito:Category",
    "Observation": "cogito:Observation",
    "ExplorationStep": "cogito:ExplorationStep",
    
    "entity": {"@id": "cogito:entity", "@type": "@id"},
    "timestamp": {"@id": "schema:dateCreated", "@type": "xsd:dateTime"},
    "action": "cogito:action",
    "reason": "schema:description",
    "note": "schema:text",
    "predicate": {"@id": "cogito:predicate", "@type": "@id"},
    "definition": "cogito:definition",
    "interpretation": "cogito:interpretation"
}

# %% [markdown]
# **AI Prompt**
#
# Ok. Now what do you suggest doing?

# %% [markdown]
# **AI Response**
#
# Now that we have a solid code structure, I suggest testing our implementation with a practical exploration. Here's what we could do next:
#
# 1. **Create a test script** that uses our `WorkflowManager` to:
#    - Start with a seed entity (like Artificial Intelligence/Q11660)
#    - Explore a few connections
#    - Analyze what the agent learns and how it builds its memory
#
# 2. **Implement a visualization component** to help us understand:
#    - The exploration path taken by the agent
#    - The knowledge graph it's building
#    - The vocabulary it's learning
#
# 3. **Add decision-making logic** to make the exploration more intelligent:
#    - Use the LLM to prioritize which connections to follow
#    - Implement different exploration strategies (breadth-first vs. depth-first)
#    - Add relevance scoring for potential paths
#
# 4. **Create a simple interactive interface** that allows us to:
#    - Guide the exploration manually when needed
#    - View the agent's memory at any point
#    - Ask questions about what the agent has learned
#
# Which of these directions would you like to pursue first? I think the test script would give us immediate feedback on our implementation, while the other options would help extend and refine the system.

# %%
# Simple test to demonstrate LLM agentic workflow with linked data

# Initialize basic components
kb = LinkedDataKnowledge()
chat = Chat(models[1])  # Claude 3 Sonnet

# Create a simple memory structure
memory = {
    "visited": set(),
    "observations": [],
    "vocabulary": {}
}

# Start with a seed entity
entity_id = "Q11660"  # Artificial Intelligence
print(f"Starting exploration with: {entity_id}")

# 1. Agent fetches the entity
kb.fetch_vocabulary(entity_id)
memory["visited"].add(entity_id)

# 2. Agent examines what it found
ai_entity = kb.find_entity_across_graphs(entity_id=entity_id)[0]

# 3. Agent interprets the entity
interpretation_prompt = f"""
I've discovered this entity about Artificial Intelligence from Wikidata.
Here's what I know about it:

{json.dumps(ai_entity, indent=2)[:1500]}...

As an AI agent exploring linked data:
1. What is the most important information I've learned about this entity?
2. Which 3 connections would be most valuable to explore next?
3. What questions should I try to answer based on this information?

Think step by step about how I should proceed in my exploration.
"""

interpretation = chat(interpretation_prompt)
print("\nAgent's interpretation:")
print(interpretation)

# 4. Agent identifies links to follow
links = []
for prop, value in ai_entity.items():
    if prop.startswith('@'): continue
    if isinstance(value, list):
        for item in value:
            if isinstance(item, dict) and '@id' in item:
                links.append((prop, item['@id']))
    elif isinstance(value, dict) and '@id' in value:
        links.append((prop, value['@id']))

print(f"\nFound {len(links)} potential connections to explore")

# 5. Agent decides which link to follow next
decision_prompt = f"""
I've identified {len(links)} connections from the Artificial Intelligence entity.
Here are the first 10 connections:
{links[:10]}

As an AI agent building knowledge about AI:
1. Which of these connections should I explore next and why?
2. How should I prioritize my exploration to build the most useful knowledge?
3. What strategy should I use to avoid getting lost in too many connections?

Recommend a specific next step in my exploration.
"""

decision = chat(decision_prompt)
print("\nAgent's decision:")
print(decision)
# Out:
# Starting exploration with: Q11660
#
# Agent's interpretation:
# ...

# %% [markdown]
# **AI Prompt**
#
# Ok. What do we think of this output?

# %% [markdown]
# **AI Response**
#
# The output demonstrates several encouraging aspects of using an LLM as an agent for linked data exploration:
#
# 1. **Meaningful Interpretation of Raw Data**:
#    - The LLM successfully extracted the core concept of AI from the entity data
#    - It identified key aspects (field of computer science, technological capability)
#    - It recognized the multilingual descriptions and noted their different emphases
#
# 2. **Strategic Exploration Planning**:
#    - The LLM identified logical areas to explore (subfields, historical development, relationships to other fields)
#    - It formulated specific questions to guide its exploration
#    - It demonstrated awareness of needing to build a comprehensive understanding
#
# 3. **Sophisticated Connection Analysis**:
#    - The LLM recognized that the first 10 connections were primarily external identifiers
#    - It correctly identified the nature of each connection (e.g., Getty AAT, Mathematics Subject Classification)
#    - It prioritized connections based on their likely knowledge value, not just their position in the list
#
# 4. **Methodical Exploration Strategy**:
#    - It recommended a structured approach (conceptual → historical → key figures → specialized resources)
#    - It suggested a breadth-first approach with depth limits to avoid getting lost
#    - It proposed periodic knowledge consolidation
#
# 5. **Domain Knowledge Application**:
#    - The LLM applied its knowledge of Wikidata properties (P279, P31, P361, etc.)
#    - It understood the significance of the Mathematics Subject Classification for AI
#    - It made informed judgments about which connections would be most valuable
#
# This test demonstrates that an LLM can effectively:
# - Make sense of complex linked data structures
# - Develop coherent exploration strategies
# - Apply domain knowledge to guide its navigation
# - Balance breadth and depth in knowledge acquisition
# - Maintain awareness of its exploration goals
#
# The approach shows promise for building more sophisticated linked data navigation agents that can autonomously explore and build knowledge while avoiding common pitfalls like getting lost in too many connections or focusing on less valuable paths.
#
# Would you like to continue this exploration by following the LLM's recommendation to explore the Mathematics Subject Classification connection?

# %%
# Continue our exploration with the Mathematics Subject Classification
msc_uri = "http://msc2010.org/resources/MSC/2010/68Txx"
print(f"Exploring Mathematics Subject Classification: {msc_uri}")

# Add this to our visited connections
memory["visited"].add(msc_uri)

# Record this in our observations
memory["observations"].append({
    "entity": entity_id,
    "property": "http://www.wikidata.org/prop/direct-normalized/P3285",
    "value": msc_uri,
    "timestamp": datetime.datetime.now().isoformat()
})

# Since MSC is an external resource, we need to fetch and interpret it
# Let's simulate this with an LLM query that explains what this classification means
msc_prompt = f"""
I'm exploring the Mathematics Subject Classification (MSC) connection from Wikidata's AI entity.
The specific MSC code is: {msc_uri} (68Txx)

As an AI agent trying to understand this classification:
1. What does this MSC code (68Txx) represent in the mathematical classification system?
2. How does this help me understand AI's relationship to mathematics?
3. What subfields or related areas might this classification include?

Please explain this classification and its significance for understanding AI.
"""

msc_interpretation = chat(msc_prompt)
print("\nAgent's interpretation of the MSC classification:")
print(msc_interpretation)

# Now let's look for conceptual properties as recommended by the LLM
# The LLM suggested looking for properties like P279 (subclass of) and P527 (has part)
print("\nLooking for conceptual properties in the AI entity...")

conceptual_properties = [
    "http://www.wikidata.org/prop/direct/P279",  # subclass of
    "http://www.wikidata.org/prop/direct/P31",   # instance of
    "http://www.wikidata.org/prop/direct/P361",  # part of
    "http://www.wikidata.org/prop/direct/P527",  # has part
    "wdt:P279", "wdt:P31", "wdt:P361", "wdt:P527"  # Prefixed versions
]

conceptual_links = []
for prop, value in ai_entity.items():
    if prop in conceptual_properties:
        if isinstance(value, list):
            for item in value:
                if isinstance(item, dict) and '@id' in item:
                    conceptual_links.append((prop, item['@id']))
        elif isinstance(value, dict) and '@id' in value:
            conceptual_links.append((prop, value['@id']))

print(f"Found {len(conceptual_links)} conceptual links")
for prop, entity in conceptual_links[:5]:
    print(f"  {prop} -> {entity}")

# If we found conceptual links, let's ask the LLM to analyze them
if conceptual_links:
    conceptual_prompt = f"""
    I've found these conceptual relationships for the AI entity:
    {conceptual_links}
    
    Please analyze these relationships and explain:
    1. What hierarchy or structure do these relationships reveal about AI?
    2. What are the most important conceptual relationships here?
    3. Which of these would be most valuable to explore next?
    
    Help me understand the conceptual framework of AI based on these links.
    """
    
    conceptual_analysis = chat(conceptual_prompt)
    print("\nAgent's analysis of conceptual relationships:")
    print(conceptual_analysis)
# Out:
# Exploring Mathematics Subject Classification: http://msc2010.org/resources/MSC/2010/68Txx
#
# Agent's interpretation of the MSC classification:
# ...

# %% [markdown]
# **AI Prompt**
#
# Ok. What do we think of the LLM response?

# %% [markdown]
# **AI Response**
#
# The LLM's responses are quite impressive and demonstrate how effectively it can serve as an agent for navigating and making sense of linked data:
#
# 1. **Mathematics Subject Classification (MSC) Analysis**:
#    - The LLM correctly interpreted the MSC code structure (68Txx)
#    - It provided detailed explanations of what each part of the code means (68 = Computer Science, T = Artificial Intelligence)
#    - It listed the specific subclassifications (68T05, 68T10, etc.) with accurate descriptions
#    - It connected the classification to related mathematical areas
#    - It explained the significance of this classification for understanding AI
#
# 2. **Conceptual Relationships Analysis**:
#    - The LLM correctly identified what each property represents (P279 = subclass of, P31 = instance of, P527 = has part)
#    - It inferred likely entities based on the QIDs (Q21198 = computer science, etc.)
#    - It organized these relationships into a coherent conceptual framework
#    - It explained the taxonomic position, ontological classification, and compositional structure of AI
#    - It provided a thoughtful prioritization for which relationships to explore next
#
# The most impressive aspects are:
#
# 1. **Knowledge Integration**: The LLM combined information from Wikidata with its own knowledge of the MSC system and AI field.
#
# 2. **Structural Understanding**: It recognized the hierarchical and compositional relationships between concepts.
#
# 3. **Strategic Exploration**: It provided well-reasoned recommendations for which paths to explore next.
#
# 4. **Context Awareness**: It maintained a clear understanding of the exploration's purpose throughout.
#
# 5. **Knowledge Organization**: It presented the information in a structured, meaningful way that builds a comprehensive mental model of AI.
#
# This demonstrates that an LLM can be an effective partner in linked data exploration, not just for retrieving information but for making sense of complex knowledge structures and guiding strategic exploration. The agent is building a rich, multi-dimensional understanding of AI through this exploration process.
#
# Would you like to continue by following one of the LLM's recommendations for the next exploration step?

# %% [markdown]
# Let's follow the LLM's recommendation to explore one of the "has part" relationships, specifically looking at machine learning (Q5514059), while implementing better response formatting.

# %%
# Let's explore the machine learning subfield of AI as recommended by the LLM
ml_entity_id = "Q5514059"  # Machine Learning
print(f"Exploring Machine Learning entity: {ml_entity_id}")

# Add to our visited entities
memory["visited"].add(ml_entity_id)

# Record this in our observations
memory["observations"].append({
    "entity": entity_id,
    "relationship": "has_part",
    "connected_entity": ml_entity_id,
    "timestamp": datetime.datetime.now().isoformat()
})

# Fetch the machine learning entity
kb.fetch_vocabulary(ml_entity_id)

# Get the entity
ml_entity = kb.find_entity_across_graphs(entity_id=ml_entity_id)[0]

# Create a better-structured prompt using techniques from the Anthropic guide
# 1. Be clear and direct with instructions
# 2. Use XML tags to structure different parts
# 3. Request a specific output format
ml_prompt = f"""
I'm exploring Machine Learning as a subfield of Artificial Intelligence.
Here's the Wikidata entity for Machine Learning (Q5514059):

<entity>
{json.dumps(ml_entity, indent=2)[:1500]}...
</entity>

<instructions>
Analyze this Machine Learning entity and provide a structured analysis with the following sections:

1. Definition and Scope: What is machine learning according to this data?
2. Relationship to AI: How does ML relate to the broader field of AI?
3. Key Components: What are the main subfields or approaches within ML?
4. Applications: What are the primary applications of ML?
5. Connections: What other fields or concepts is ML connected to?

For each section, cite specific evidence from the entity data when possible.
Format your response using markdown with clear headings, bullet points, and concise paragraphs.
Limit each section to 3-5 key points for readability.
</instructions>
"""

ml_analysis = chat(ml_prompt)
print("\nStructured Analysis of Machine Learning:")
print(ml_analysis)

# Now let's find connections between ML and other entities
# Let's specifically look for subfields of machine learning
print("\nLooking for subfields of Machine Learning...")

# Use the LLM to help us identify which connections to follow
connections_prompt = f"""
<context>
I'm building a knowledge graph about AI and its subfields. I've explored:
1. Artificial Intelligence (Q11660)
2. Machine Learning (Q5514059) - a subfield of AI

I want to identify the most important subfields of Machine Learning to explore next.
</context>

<entity>
{json.dumps(ml_entity, indent=2)[:1500]}...
</entity>

<instructions>
Based on the Machine Learning entity data and your knowledge:

1. Identify 3-5 major subfields of Machine Learning that would be important to explore
2. For each subfield:
   - Provide its likely Wikidata ID if you can infer it
   - Explain why this subfield is important to understanding ML
   - Describe what unique perspective it adds to our knowledge graph

Format your response as a concise, structured list with clear headings and brief explanations.
</instructions>
"""

connections_analysis = chat(connections_prompt)
print("\nRecommended ML Subfields to Explore:")
print(connections_analysis)
# Out:
# Exploring Machine Learning entity: Q5514059
#
# Structured Analysis of Machine Learning:
# ...

# %% [markdown]
# **AI Prompt**
#
# Ok. What do we think of this response?

# %% [markdown]
# **AI Response**
#
# The improved prompt formatting has produced much more readable and structured responses. Here's what stands out:
#
# 1. **Better Organization and Readability**:
#    - Clear section headings and concise bullet points
#    - Consistent formatting throughout
#    - Proper use of markdown for hierarchy and emphasis
#    - Limited content in each section for better digestibility
#
# 2. **Insightful Content Analysis**:
#    - The LLM identified a potential discrepancy in the Wikidata entity - it appears to be describing symbolic AI rather than machine learning in its contemporary sense
#    - It correctly noted that the entity focuses on an earlier historical period (1950s-1980s)
#    - It properly distinguished between symbolic approaches and modern ML techniques
#
# 3. **Critical Thinking**:
#    - The LLM didn't just accept the entity data at face value
#    - It identified limitations in the data and potential categorization issues
#    - It added a thoughtful "Note" section highlighting the discrepancy
#
# 4. **Strategic Recommendations**:
#    - The subfield recommendations directly address the gap in the current entity
#    - Each recommendation includes Wikidata IDs, importance, and unique perspective
#    - The suggestions would create a more complete and accurate representation of ML
#
# 5. **Contextual Awareness**:
#    - The LLM maintained awareness of our exploration journey
#    - It connected new information to previously explored entities
#    - It built upon the evolving knowledge graph we're creating
#
# This demonstrates that structured prompting using XML tags, clear instructions, and specific formatting requests significantly improves the quality and usability of the LLM's responses. The Anthropic prompting techniques have helped transform the output from a wall of text into a well-organized, easy-to-navigate analysis that would be much more useful for an agent navigating linked data.
#
# Would you like to continue our exploration by following one of the LLM's subfield recommendations, or should we reflect on what we've learned about designing an effective linked data agent?

# %%
def format_llm_response(response):
    """Extract the text content from an LLM response and return it as markdown"""
    if hasattr(response, 'content'):
        for block in response.content:
            if hasattr(block, 'text'):
                return block.text
    # Fallback if we can't extract text properly
    return str(response)

# Example using the function with our existing code
ml_prompt = f"""
I'm exploring Machine Learning as a subfield of Artificial Intelligence.
Here's the Wikidata entity for Machine Learning (Q5514059):

<entity>
{json.dumps(ml_entity, indent=2)[:1500]}...
</entity>

<instructions>
Analyze this Machine Learning entity and provide a structured analysis with the following sections:

1. Definition and Scope: What is machine learning according to this data?
2. Relationship to AI: How does ML relate to the broader field of AI?
3. Key Components: What are the main subfields or approaches within ML?
4. Applications: What are the primary applications of ML?
5. Connections: What other fields or concepts is ML connected to?

For each section, cite specific evidence from the entity data when possible.
Format your response using markdown with clear headings, bullet points, and concise paragraphs.
Limit each section to 3-5 key points for readability.
</instructions>
"""

ml_analysis = chat(ml_prompt)
formatted_analysis = format_llm_response(ml_analysis)

# Use IPython's display functionality if available
try:
    from IPython.display import display, Markdown
    display(Markdown(formatted_analysis))
except ImportError:
    # If not in an IPython environment, print the formatted text
    print("\nStructured Analysis of Machine Learning:")
    print(formatted_analysis)
# Out:
# # Analysis of Machine Learning (Q5514059) Entity
#
# ## 1. Definition and Scope
#
# Based on the entity data, Machine Learning appears to be defined as:
#
# * **Symbolic AI approach**: "methods in artificial intelligence research that are based on high-level symbolic representations of problems, logic and search" (English description)
# * **Historical significance**: "dominant from the 1950s until the 1980s" (English description)
# * **Human-readable representations**: The Persian description mentions "high-level symbolic (human-readable) representations"
#
# Interestingly, this description seems to focus specifically on symbolic/logical approaches to machine learning rather than the broader statistical and neural network approaches that are common today.
#
# ## 2. Relationship to AI
#
# The entity data indicates that Machine Learning:
#
# * **Subfield of AI**: The entity is referenced as part of the broader AI entity (Q11660) through the "has part" (P527) relationship
# ...

# %% [markdown]
# **AI Prompt**
#
# Ok. Let's take a step back and think through this dialog of what our experiments have shown and what approaches for hybrid software 1.0/software 2.0 would help generalize the problem. We want some combination of software tools for LLM agents to enable discovery and consistent linked data retrevial and hide the complexity of retreiving linked data. Some tools that guide the structuring of memory. And then a software 2.0 component where the LLM handles much of the work.

# %% [markdown]
# **AI Response**
#
# Our experiments have demonstrated a promising approach for hybrid Software 1.0/2.0 systems that enable LLMs to effectively navigate, understand, and utilize linked data. Let's analyze what we've learned and how to generalize this approach.
#
# ## Key Insights from Our Experiments
#
# 1. **Division of Responsibilities**:
#    - **Software 1.0 (Traditional Code)**: Handles technical operations like fetching, parsing, and storing linked data
#    - **Software 2.0 (LLM)**: Handles semantic interpretation, decision-making, and knowledge organization
#
# 2. **Memory Structure Requirements**:
#    - A flexible, semantic structure (JSON-LD) provides both machine-readable and LLM-interpretable organization
#    - Memory needs to track: visited entities, exploration paths, observations, and vocabulary understanding
#
# 3. **Effective Prompting Patterns**:
#    - Structured prompts with XML tags dramatically improve LLM response quality
#    - Clear instructions about expected format and content yield more usable outputs
#    - Context about the exploration journey helps maintain coherence
#
# 4. **LLM Strengths in Linked Data Navigation**:
#    - Identifying meaningful patterns across diverse data
#    - Making informed decisions about which connections to follow
#    - Detecting discrepancies and potential issues in the data
#    - Providing context and interpretation beyond what's explicitly stated
#
# ## Generalized Architecture Proposal
#
# Based on our experiments, here's a generalized architecture for hybrid linked data navigation:
#
# ### 1. Data Layer (Software 1.0)
# - **LinkedDataFetcher**: Handles retrieval from various sources with content negotiation
# - **EntityParser**: Normalizes entities from different sources into consistent format
# - **MemoryStore**: Maintains the JSON-LD knowledge structure with indexing capabilities
#
# ### 2. Navigation Layer (Software 1.0)
# - **PathTracker**: Records exploration history and prevents cycles
# - **ConnectionIdentifier**: Extracts potential connections from entities
# - **VocabularyRegistry**: Tracks and resolves property and class definitions
#
# ### 3. Semantic Layer (Software 2.0)
# - **EntityInterpreter**: LLM component that extracts meaning from entities
# - **NavigationAdvisor**: LLM component that recommends which paths to follow
# - **DiscrepancyDetector**: LLM component that identifies issues in the data
# - **KnowledgeOrganizer**: LLM component that structures accumulated knowledge
#
# ### 4. Coordination Layer (Hybrid)
# - **ExplorationManager**: Orchestrates the overall process, balancing code and LLM
# - **PromptGenerator**: Creates structured prompts based on current context and needs
# - **ResponseProcessor**: Extracts and formats LLM outputs for both human and machine use
#
# ## Practical Implementation Approach
#
# To implement this architecture effectively:
#
# 1. **Start with minimal viable components**:
#    - Basic fetching and parsing functionality
#    - Simple memory structure
#    - Core LLM interpretation capabilities
#
# 2. **Evolve iteratively based on exploration needs**:
#    - Add specialized components as patterns emerge
#    - Refine prompting strategies based on response quality
#    - Enhance memory organization as knowledge accumulates
#
# 3. **Maintain flexibility**:
#    - Design for different exploration strategies (breadth-first, depth-first, interest-driven)
#    - Support multiple linked data sources and formats
#    - Allow for both autonomous and human-guided exploration
#
# Would you like me to elaborate on any specific aspect of this architecture or discuss how to implement a particular component?

# %% [markdown]
# **AI Prompt**
#
# Have we demonstrated LLM based memory retreival?

# %% [markdown]
# **AI Response**
#
# You raise an important point. In our experiments, we've focused primarily on knowledge acquisition, interpretation, and navigation, but we haven't fully demonstrated LLM-based memory retrieval.
#
# What we've shown so far:
# - LLMs can interpret linked data entities
# - LLMs can recommend navigation paths
# - LLMs can organize acquired knowledge
#
# What we haven't fully demonstrated:
# - LLMs retrieving specific information from previously stored memory
# - LLMs answering questions based on accumulated knowledge
# - LLMs synthesizing information across multiple stored entities
#
# To properly demonstrate LLM-based memory retrieval, we would need to:
#
# 1. Build up a substantial memory store with multiple related entities
# 2. Ask the LLM to retrieve specific information from this memory
# 3. Test how well it can combine information from different entities
# 4. Evaluate its ability to answer questions that require synthesizing stored knowledge
#
# This would involve adding components like:
# - A **MemoryRetriever** that can surface relevant stored entities based on a query
# - A **KnowledgeSynthesizer** that combines information across multiple entities
# - A **QueryResponder** that formulates answers based on retrieved memory
#
# Would you like to design an experiment to test LLM-based memory retrieval specifically? This would complement our existing work on knowledge acquisition and navigation.

# %% [markdown]
# **AI Prompt**
#
# So. Can we do the experiment without writing extensive new code? I just want an exploratory approch to see what this will look like.

# %% [markdown]
# **AI Response**
#
# Absolutely! We can design a lightweight exploratory experiment to test LLM-based memory retrieval using our existing code structure. Here's a minimal approach:
#
# 1. First, let's use our existing memory that already contains information about:
#    - Artificial Intelligence (Q11660)
#    - Machine Learning (Q5514059)
#    - The relationships between them
#    - The MSC classification information
#
# 2. We'll create a simple function to format our memory in a way the LLM can process
#
# 3. Then we'll craft a query prompt that asks the LLM to retrieve specific information
#
# Let's sketch this out:
#
# ```python
# # Format our existing memory for retrieval
# def prepare_memory_for_retrieval(memory, kb):
#     """Format memory contents for LLM retrieval"""
#     # Create a summary of what's in our memory
#     memory_summary = {
#         "entities_visited": list(memory["visited"]),
#         "observations": memory["observations"],
#         "vocabulary": memory["vocabulary"]
#     }
#
#     # Include a simplified version of each entity we've explored
#     entity_summaries = {}
#     for entity_id in memory["visited"]:
#         entities = kb.find_entity_across_graphs(entity_id=entity_id)
#         if entities:
#             # Just include key information for each entity
#             entity = entities[0]
#             entity_summaries[entity_id] = {
#                 "id": entity_id,
#                 "label": entity.get("label", "Unknown"),
#                 "description": entity.get("description", "No description available"),
#                 # Include a few key properties
#                 "properties": {k: v for k, v in entity.items()
#                               if k not in ["@id", "@type", "label", "description"]}[:5]
#             }
#
#     memory_summary["entity_summaries"] = entity_summaries
#     return memory_summary
#
# # Test retrieval with a specific question
# def retrieve_from_memory(question, memory_summary, chat):
#     """Use LLM to retrieve information from memory"""
#     retrieval_prompt = f"""
#     <memory>
#     {json.dumps(memory_summary, indent=2)}
#     </memory>
#
#     <question>
#     {question}
#     </question>
#
#     <instructions>
#     Based ONLY on the information in the memory provided above:
#     1. Identify which pieces of information in memory are relevant to the question
#     2. Retrieve the specific facts needed to answer the question
#     3. Provide a clear, concise answer using only the information available in memory
#     4. If the information in memory is insufficient, state what's missing
#
#     Format your response as:
#
#     RELEVANT MEMORY: [list specific parts of memory that are relevant]
#
#     RETRIEVED FACTS: [list specific facts retrieved from memory]
#
#     ANSWER: [provide answer based only on memory]
#
#     GAPS: [note any information gaps in memory]
#     </instructions>
#     """
#
#     response = chat(retrieval_prompt)
#     return response
# ```
#
# Let's test this with a few different types of questions:
#
# 1. Factual question: "What is the relationship between AI and Machine Learning?"
# 2. Comparative question: "How does the definition of Machine Learning in Wikidata compare to modern understanding?"
# 3. Synthesis question: "Based on our exploration, what are the key mathematical foundations of AI?"
#
# Would you like to proceed with this exploratory approach to test memory retrieval?

# %%
#| export
def prepare_memory_for_retrieval(memory, kb):
    """Format memory contents for LLM retrieval"""
    # Create a summary of what's in our memory
    memory_summary = {
        "entities_visited": list(memory["visited"]),
        "observations": memory["observations"],
        "vocabulary": memory["vocabulary"]
    }
    
    # Include a simplified version of each entity we've explored
    entity_summaries = {}
    for entity_id in memory["visited"]:
        entities = kb.find_entity_across_graphs(entity_id=entity_id)
        if entities:
            # Just include key information for each entity
            entity = entities[0]
            
            # Get a few key properties (correctly this time)
            key_properties = {}
            count = 0
            for k, v in entity.items():
                if k not in ["@id", "@type", "label", "description"]:
                    key_properties[k] = v
                    count += 1
                    if count >= 5:
                        break
            
            entity_summaries[entity_id] = {
                "id": entity_id,
                "label": entity.get("label", "Unknown"),
                "description": entity.get("description", "No description available"),
                "properties": key_properties
            }
    
    memory_summary["entity_summaries"] = entity_summaries
    return memory_summary

# %%
#| export
# Test retrieval with a specific question
def retrieve_from_memory(question, memory_summary, chat):
    """Use LLM to retrieve information from memory"""
    retrieval_prompt = f"""
    <memory>
    {json.dumps(memory_summary, indent=2)}
    </memory>
    
    <question>
    {question}
    </question>
    
    <instructions>
    Based ONLY on the information in the memory provided above:
    1. Identify which pieces of information in memory are relevant to the question
    2. Retrieve the specific facts needed to answer the question
    3. Provide a clear, concise answer using only the information available in memory
    4. If the information in memory is insufficient, state what's missing
    
    Format your response as:
    
    RELEVANT MEMORY: [list specific parts of memory that are relevant]
    
    RETRIEVED FACTS: [list specific facts retrieved from memory]
    
    ANSWER: [provide answer based only on memory]
    
    GAPS: [note any information gaps in memory]
    </instructions>
    """
    
    response = chat(retrieval_prompt)
    return response

# %% [markdown]
# **AI Prompt**
#
# Ok. What is the next step in testing this approach?

# %% [markdown]
# **AI Response**
#
# The next step in testing this approach is to implement and run our memory retrieval experiment. Here's what we need to do:
#
# 1. Prepare our existing memory data for retrieval
# 2. Format the LLM interpretations we've already collected
# 3. Test with a few specific questions to see how well the LLM can retrieve information
#
# Let's implement this step by step:
#
# ```python
# # First, prepare our memory data
# memory_data = prepare_memory_for_retrieval(memory, kb)
#
# # Add the LLM interpretations we've already collected
# memory_data["interpretations"] = [
#     {
#         "entity_id": "Q11660",  # AI
#         "interpretation": format_llm_response(interpretation)
#     },
#     {
#         "entity_id": "Q5514059",  # Machine Learning
#         "interpretation": format_llm_response(ml_analysis)
#     },
#     {
#         "entity_id": "MSC:68Txx",  # Mathematics Subject Classification
#         "interpretation": format_llm_response(msc_interpretation)
#     },
#     {
#         "entity_id": "conceptual_relationships",
#         "interpretation": format_llm_response(conceptual_analysis)
#     }
# ]
#
# # Test with our factual question
# factual_question = "What is the relationship between AI and Machine Learning?"
# factual_response = retrieve_from_memory(factual_question, memory_data, chat)
# print(f"\n\nQuestion: {factual_question}")
# print(format_llm_response(factual_response))
#
# # Test with our comparative question
# comparative_question = "How does the definition of Machine Learning in Wikidata compare to modern understanding?"
# comparative_response = retrieve_from_memory(comparative_question, memory_data, chat)
# print(f"\n\nQuestion: {comparative_question}")
# print(format_llm_response(comparative_response))
#
# # Test with our synthesis question
# synthesis_question = "Based on our exploration, what are the key mathematical foundations of AI?"
# synthesis_response = retrieve_from_memory(synthesis_question, memory_data, chat)
# print(f"\n\nQuestion: {synthesis_question}")
# print(format_llm_response(synthesis_response))
# ```
#
# This will give us a clear picture of:
#
# 1. How well the LLM can identify relevant information in memory
# 2. Whether it can accurately retrieve specific facts
# 3. If it can synthesize information across different parts of memory
# 4. Where the gaps in our memory structure might be
#
# Would you like to implement this test now? We can then analyze the results to understand the strengths and limitations of LLM-based memory retrieval.

# %%
# First, prepare our memory data
memory_data = prepare_memory_for_retrieval(memory, kb)

# Add the LLM interpretations we've already collected
memory_data["interpretations"] = [
    {
        "entity_id": "Q11660",  # AI
        "interpretation": format_llm_response(interpretation)
    },
    {
        "entity_id": "Q5514059",  # Machine Learning
        "interpretation": format_llm_response(ml_analysis)
    },
    {
        "entity_id": "MSC:68Txx",  # Mathematics Subject Classification
        "interpretation": format_llm_response(msc_interpretation)
    },
    {
        "entity_id": "conceptual_relationships",
        "interpretation": format_llm_response(conceptual_analysis)
    }
]

# Test with our factual question
factual_question = "What is the relationship between AI and Machine Learning?"
factual_response = retrieve_from_memory(factual_question, memory_data, chat)
print(f"\n\nQuestion: {factual_question}")
print(format_llm_response(factual_response))

# Test with our comparative question
comparative_question = "How does the definition of Machine Learning in Wikidata compare to modern understanding?"
comparative_response = retrieve_from_memory(comparative_question, memory_data, chat)
print(f"\n\nQuestion: {comparative_question}")
print(format_llm_response(comparative_response))

# Test with our synthesis question
synthesis_question = "Based on our exploration, what are the key mathematical foundations of AI?"
synthesis_response = retrieve_from_memory(synthesis_question, memory_data, chat)
print(f"\n\nQuestion: {synthesis_question}")
print(format_llm_response(synthesis_response))
# Out:
# Question: What is the relationship between AI and Machine Learning?
# # RELEVANT MEMORY:
# - Entity Q11660 (Artificial Intelligence) has a "has part" (P527) relationship with Q5514059
# - Entity Q5514059 is labeled as "symbolic artificial intelligence" but was initially explored as "Machine Learning"
# - The interpretation of Q5514059 describes it as a "subfield of AI" through the "has part" (P527) relationship
# - The description of Q5514059 focuses on "methods in artificial intelligence research that are based on high-level symbolic representations of problems, logic and search, dominant from the 1950s until the 1980s"
#
# # RETRIEVED FACTS:
# - AI (Q11660) has a "has part" (P527) relationship with Q5514059
# - Q5514059 is described as "methods in artificial intelligence research that are based on high-level symbolic representations of problems, logic and search, dominant from the 1950s until the 1980s"
# ...

# %% [markdown]
# **AI Prompt**
#
# What do we think of this output? What about in relation to our memory test?

# %% [markdown]
# **AI Response**
#
# The output from our memory retrieval experiment is quite impressive and demonstrates several key insights about LLM-based memory retrieval:
#
# ### Strengths Demonstrated
#
# 1. **Structured Information Retrieval**:
#    - The LLM successfully identified relevant sections of memory for each question
#    - It extracted specific facts that directly addressed the questions
#    - It organized its responses in a clear, structured format following our instructions
#
# 2. **Critical Awareness of Memory Limitations**:
#    - The LLM correctly identified the mismatch between the entity ID (Q5514059) being explored as "Machine Learning" when it actually represents "symbolic artificial intelligence"
#    - It accurately noted gaps in the memory, such as missing information about modern machine learning approaches
#    - It maintained awareness of what it does and doesn't know based on the provided memory
#
# 3. **Cross-Reference Capability**:
#    - The LLM effectively synthesized information across different memory entries
#    - For the mathematical foundations question, it combined information from the MSC classification with details from the entity interpretations
#    - It connected concepts across different memory sections to form coherent answers
#
# 4. **Contextual Understanding**:
#    - The LLM understood the temporal context (e.g., symbolic AI being dominant from 1950s-1980s)
#    - It recognized the hierarchical relationships between concepts
#    - It maintained awareness of the exploration journey that led to the current memory state
#
# ### Areas for Improvement
#
# 1. **Memory Structure Optimization**:
#    - The experiment reveals that our current memory structure could be improved to better support retrieval
#    - Adding explicit metadata about entity relationships would help with navigation
#    - Standardizing how interpretations are stored would improve consistency
#
# 2. **Knowledge Verification**:
#    - The LLM identified but couldn't resolve the confusion about the Machine Learning entity
#    - A verification step could help catch and correct such misidentifications earlier
#
# 3. **Memory Completion Mechanisms**:
#    - The LLM identified gaps but couldn't fill them autonomously
#    - Adding a mechanism to proactively identify and fill knowledge gaps would be valuable
#
# ### Overall Assessment
#
# This experiment demonstrates that LLMs can effectively:
# 1. Navigate complex memory structures
# 2. Retrieve relevant information based on questions
# 3. Synthesize across different memory components
# 4. Maintain awareness of memory limitations
#
# The structured approach to memory retrieval, with clear sections for relevant memory, retrieved facts, answers, and gaps, provides a strong foundation for more sophisticated memory systems. The LLM's ability to identify discrepancies and gaps also suggests it could help guide the knowledge acquisition process, pointing to areas that need further exploration.
#
# Would you like to discuss how we might improve the memory structure or retrieval process based on these results?

# %% [markdown]
# Applying the 80/20 principle to our linked data agent development, here's what we should focus on first:
#
# ## Highest-Impact Improvements (20% effort for 80% results)
#
# 1. **Standardized Memory Structure**:
#    - Implement a consistent JSON-LD structure for all memory entries
#    - Ensure every entity has standardized metadata (label, description, type)
#    - Create explicit relationship links between entities
#
# 2. **Enhanced Retrieval Prompting**:
#    - Refine our retrieval prompt template to include explicit instructions about handling uncertainty
#    - Add a "confidence level" section to the output format
#    - Include memory navigation hints in the prompt
#
# 3. **Verification Loop**:
#    - Add a simple verification step where the LLM checks its own interpretations for inconsistencies
#    - Flag potential mismatches between entity IDs and their interpretations
#    - Create a correction mechanism for identified errors
#
# 4. **Gap Identification System**:
#    - Implement a process to explicitly track knowledge gaps identified during exploration
#    - Prioritize these gaps for future exploration
#    - Create a simple scoring mechanism for the importance of filling each gap
#
# These four improvements would address the most critical issues we've identified while requiring relatively little implementation effort. They focus on making the existing system more robust rather than adding complex new features.
#
# The single most important first step would be standardizing the memory structure, as this provides the foundation for all other improvements. A consistent, well-structured memory makes retrieval, verification, and gap identification much more effective.

# %% [markdown]
# **AI Prompt**
#
# Ok. Let's refine our memory structure.

# %% [markdown]
# **AI Response**
#
# Let's refine our memory structure to better support LLM-based retrieval and navigation. Based on our experiments, here's a more optimized JSON-LD structure:
#
# ```python
# REFINED_MEMORY_CONTEXT = {
#     "@version": 1.1,
#     "schema": "https://schema.org/",
#     "cogito": "https://cogitarelink.ai/ns#",
#     "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
#     "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
#
#     # Core memory sections
#     "entities": "cogito:knownEntities",
#     "paths": "cogito:explorationPaths",
#     "observations": "cogito:observations",
#     "vocabularies": "cogito:vocabularyRegistry",
#     "relationships": "cogito:entityRelationships",
#     "gaps": "cogito:knowledgeGaps",
#
#     # Entity types
#     "Entity": "cogito:Entity",
#     "Property": "cogito:Property",
#     "Observation": "cogito:Observation",
#     "Path": "cogito:ExplorationPath",
#     "Gap": "cogito:KnowledgeGap",
#     "Relationship": "cogito:EntityRelationship",
#
#     # Common properties
#     "id": "@id",
#     "type": "@type",
#     "label": "rdfs:label",
#     "description": "rdfs:comment",
#     "source": "cogito:source",
#     "timestamp": {"@id": "schema:dateCreated", "@type": "xsd:dateTime"},
#     "confidence": "cogito:confidenceScore",
#     "interpretation": "cogito:llmInterpretation",
#
#     # Relationship properties
#     "subject": {"@id": "cogito:subject", "@type": "@id"},
#     "predicate": {"@id": "cogito:predicate", "@type": "@id"},
#     "object": {"@id": "cogito:object", "@type": "@id"},
#     "predicateLabel": "cogito:predicateLabel",
#
#     # Gap properties
#     "gapType": "cogito:gapType",
#     "priority": "cogito:priority",
#     "relatedEntity": {"@id": "cogito:relatedEntity", "@type": "@id"}
# }
# ```
#
# Now let's create a refined memory structure:
#
# ```python
# def create_refined_memory():
#     """Create a refined memory structure based on our experiments"""
#     return {
#         "@context": REFINED_MEMORY_CONTEXT,
#         "@id": "cogito:memory1",
#         "@type": "cogito:AgentMemory",
#
#         "entities": {},  # Entities keyed by ID
#         "relationships": [],  # Explicit relationships between entities
#         "paths": [],  # Exploration path history
#         "observations": [],  # Observations about entities
#         "vocabularies": {},  # Property and class definitions
#         "gaps": []  # Identified knowledge gaps
#     }
# ```
#
# Let's enhance our entity storage to include standardized metadata:
#
# ```python
# def add_entity_to_memory(memory, entity_id, entity_data, llm_interpretation=None):
#     """Add an entity to memory with standardized metadata"""
#     # Extract basic metadata
#     label = entity_data.get("label", "Unknown")
#     if isinstance(label, list) and len(label) > 0:
#         label = label[0]  # Take first label if it's a list
#
#     description = entity_data.get("description", "")
#     if isinstance(description, list) and len(description) > 0:
#         description = description[0]  # Take first description if it's a list
#
#     entity_type = entity_data.get("@type", "Unknown")
#
#     # Create standardized entity entry
#     memory["entities"][entity_id] = {
#         "@id": entity_id,
#         "@type": "Entity",
#         "label": label,
#         "description": description,
#         "entityType": entity_type,
#         "timestamp": datetime.datetime.now().isoformat(),
#         "source": "wikidata",  # Or other source as appropriate
#         "rawData": entity_data,  # Store the full raw data
#         "confidence": 1.0  # Default high confidence for direct data
#     }
#
#     # Add LLM interpretation if provided
#     if llm_interpretation:
#         memory["entities"][entity_id]["interpretation"] = {
#             "text": llm_interpretation,
#             "timestamp": datetime.datetime.now().isoformat()
#         }
#
#     return memory
# ```
#
# Let's also add a function to explicitly track relationships between entities:
#
# ```python
# def add_relationship_to_memory(memory, subject_id, predicate, object_id, predicate_label=None):
#     """Add an explicit relationship between entities"""
#     relationship = {
#         "@type": "Relationship",
#         "subject": subject_id,
#         "predicate": predicate,
#         "object": object_id,
#         "timestamp": datetime.datetime.now().isoformat()
#     }
#
#     if predicate_label:
#         relationship["predicateLabel"] = predicate_label
#
#     memory["relationships"].append(relationship)
#     return memory
# ```
#
# Finally, let's add a function to track knowledge gaps:
#
# ```python
# def add_gap_to_memory(memory, gap_description, gap_type, related_entity=None, priority="medium"):
#     """Track an identified knowledge gap"""
#     gap = {
#         "@type": "Gap",
#         "description": gap_description,
#         "gapType": gap_type,  # e.g., "missing_entity", "incomplete_info", "contradiction"
#         "priority": priority,  # "high", "medium", "low"
#         "timestamp": datetime.datetime.now().isoformat(),
#         "status": "identified"  # Could later be "addressed", "ignored", etc.
#     }
#
#     if related_entity:
#         gap["relatedEntity"] = related_entity
#
#     memory["gaps"].append(gap)
#     return memory
# ```
#
# Would you like to implement this refined memory structure and test it with our existing data?

# %%
REFINED_MEMORY_CONTEXT = {
    "@version": 1.1,
    "schema": "https://schema.org/",
    "cogito": "https://cogitarelink.ai/ns#",
    "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
    "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
    
    # Core memory sections
    "entities": "cogito:knownEntities",
    "paths": "cogito:explorationPaths",
    "observations": "cogito:observations",
    "vocabularies": "cogito:vocabularyRegistry",
    "relationships": "cogito:entityRelationships",
    "gaps": "cogito:knowledgeGaps",
    
    # Entity types
    "Entity": "cogito:Entity",
    "Property": "cogito:Property",
    "Observation": "cogito:Observation",
    "Path": "cogito:ExplorationPath",
    "Gap": "cogito:KnowledgeGap",
    "Relationship": "cogito:EntityRelationship",
    
    # Common properties
    "id": "@id",
    "type": "@type",
    "label": "rdfs:label",
    "description": "rdfs:comment",
    "source": "cogito:source",
    "timestamp": {"@id": "schema:dateCreated", "@type": "xsd:dateTime"},
    "confidence": "cogito:confidenceScore",
    "interpretation": "cogito:llmInterpretation",
    
    # Relationship properties
    "subject": {"@id": "cogito:subject", "@type": "@id"},
    "predicate": {"@id": "cogito:predicate", "@type": "@id"},
    "object": {"@id": "cogito:object", "@type": "@id"},
    "predicateLabel": "cogito:predicateLabel",
    
    # Gap properties
    "gapType": "cogito:gapType",
    "priority": "cogito:priority",
    "relatedEntity": {"@id": "cogito:relatedEntity", "@type": "@id"}
}

# %%
def create_refined_memory():
    """Create a refined memory structure based on our experiments"""
    return {
        "@context": REFINED_MEMORY_CONTEXT,
        "@id": "cogito:memory1",
        "@type": "cogito:AgentMemory",
        
        "entities": {},  # Entities keyed by ID
        "relationships": [],  # Explicit relationships between entities
        "paths": [],  # Exploration path history
        "observations": [],  # Observations about entities
        "vocabularies": {},  # Property and class definitions
        "gaps": []  # Identified knowledge gaps
    }

# %%
def add_entity_to_memory(memory, entity_id, entity_data, llm_interpretation=None):
    """Add an entity to memory with standardized metadata"""
    # Extract basic metadata
    label = entity_data.get("label", "Unknown")
    if isinstance(label, list) and len(label) > 0:
        label = label[0]  # Take first label if it's a list
    
    description = entity_data.get("description", "")
    if isinstance(description, list) and len(description) > 0:
        description = description[0]  # Take first description if it's a list
    
    entity_type = entity_data.get("@type", "Unknown")
    
    # Create standardized entity entry
    memory["entities"][entity_id] = {
        "@id": entity_id,
        "@type": "Entity",
        "label": label,
        "description": description,
        "entityType": entity_type,
        "timestamp": datetime.datetime.now().isoformat(),
        "source": "wikidata",  # Or other source as appropriate
        "rawData": entity_data,  # Store the full raw data
        "confidence": 1.0  # Default high confidence for direct data
    }
    
    # Add LLM interpretation if provided
    if llm_interpretation:
        memory["entities"][entity_id]["interpretation"] = {
            "text": llm_interpretation,
            "timestamp": datetime.datetime.now().isoformat()
        }
    
    return memory

# %%
def add_relationship_to_memory(memory, subject_id, predicate, object_id, predicate_label=None):
    """Add an explicit relationship between entities"""
    relationship = {
        "@type": "Relationship",
        "subject": subject_id,
        "predicate": predicate,
        "object": object_id,
        "timestamp": datetime.datetime.now().isoformat()
    }
    
    if predicate_label:
        relationship["predicateLabel"] = predicate_label
    
    memory["relationships"].append(relationship)
    return memory

# %%
def add_gap_to_memory(memory, gap_description, gap_type, related_entity=None, priority="medium"):
    """Track an identified knowledge gap"""
    gap = {
        "@type": "Gap",
        "description": gap_description,
        "gapType": gap_type,  # e.g., "missing_entity", "incomplete_info", "contradiction"
        "priority": priority,  # "high", "medium", "low"
        "timestamp": datetime.datetime.now().isoformat(),
        "status": "identified"  # Could later be "addressed", "ignored", etc.
    }
    
    if related_entity:
        gap["relatedEntity"] = related_entity
    
    memory["gaps"].append(gap)
    return memory

# %%
# Create our refined memory
refined_memory = create_refined_memory()

# Migrate our existing AI entity
ai_entity_id = "http://www.wikidata.org/entity/Q11660"
ai_interpretation = format_llm_response(interpretation)
refined_memory = add_entity_to_memory(
    refined_memory, 
    ai_entity_id, 
    ai_entity, 
    ai_interpretation
)

# Migrate our ML entity
ml_entity_id = "http://www.wikidata.org/entity/Q5514059"
ml_interpretation = format_llm_response(ml_analysis)
refined_memory = add_entity_to_memory(
    refined_memory, 
    ml_entity_id, 
    ml_entity, 
    ml_interpretation
)

# Add the MSC classification as a separate entity
msc_entity_id = "http://msc2010.org/resources/MSC/2010/68Txx"
msc_interp = format_llm_response(msc_interpretation)
# Since we don't have the raw data, we'll create a minimal entity
msc_entity_data = {
    "@id": msc_entity_id,
    "@type": "Classification",
    "label": "Mathematics Subject Classification: 68Txx (AI)"
}
refined_memory = add_entity_to_memory(
    refined_memory,
    msc_entity_id,
    msc_entity_data,
    msc_interp
)

# Add explicit relationships between entities
# AI has_part ML relationship
refined_memory = add_relationship_to_memory(
    refined_memory,
    ai_entity_id,
    "http://www.wikidata.org/prop/direct/P527",
    ml_entity_id,
    "has part"
)

# AI classified_by MSC relationship
refined_memory = add_relationship_to_memory(
    refined_memory,
    ai_entity_id,
    "http://www.wikidata.org/prop/direct-normalized/P3285",
    msc_entity_id,
    "mathematics subject classification"
)

# Add knowledge gaps we identified
refined_memory = add_gap_to_memory(
    refined_memory,
    "Current ML entity (Q5514059) represents symbolic AI rather than modern machine learning",
    "entity_mismatch",
    ml_entity_id,
    "high"
)

refined_memory = add_gap_to_memory(
    refined_memory,
    "Missing information about modern machine learning approaches (neural networks, statistical methods)",
    "missing_information",
    ai_entity_id,
    "high"
)

refined_memory = add_gap_to_memory(
    refined_memory,
    "No detailed information about the mathematical formulations and theorems underlying AI",
    "incomplete_information",
    msc_entity_id,
    "medium"
)

# Now let's create an enhanced retrieval function for our refined memory
def enhanced_retrieve_from_memory(question, refined_memory, chat):
    """Enhanced retrieval from refined memory structure"""
    
    # Create a more structured view of the memory for the LLM
    memory_view = {
        "entities": {
            entity_id: {
                "label": entity["label"],
                "description": entity["description"],
                "interpretation": entity.get("interpretation", {}).get("text", "No interpretation available")
            } for entity_id, entity in refined_memory["entities"].items()
        },
        "relationships": [
            {
                "subject": rel["subject"],
                "predicate": rel["predicate"],
                "predicateLabel": rel.get("predicateLabel", "unknown relation"),
                "object": rel["object"]
            } for rel in refined_memory["relationships"]
        ],
        "gaps": [
            {
                "description": gap["description"],
                "type": gap["gapType"],
                "priority": gap["priority"],
                "relatedEntity": gap.get("relatedEntity", "none")
            } for gap in refined_memory["gaps"]
        ]
    }
    
    # Create an enhanced prompt that leverages our refined structure
    retrieval_prompt = f"""
    <memory>
    {json.dumps(memory_view, indent=2)}
    </memory>
    
    <question>
    {question}
    </question>
    
    <instructions>
    Based ONLY on the information in the memory provided above:
    
    1. Identify which entities and relationships in memory are relevant to the question
    2. Retrieve the specific facts needed to answer the question
    3. Provide a clear, concise answer using only the information available in memory
    4. Acknowledge any relevant knowledge gaps that affect your answer
    5. Assign a confidence score (1-5) to your answer based on the completeness of information
    
    Format your response as:
    
    RELEVANT ENTITIES: [list specific entities that are relevant]
    
    RELEVANT RELATIONSHIPS: [list relationships between entities that matter]
    
    RETRIEVED FACTS: [list specific facts retrieved from memory]
    
    ANSWER: [provide answer based only on memory]
    
    KNOWLEDGE GAPS: [note any relevant gaps that affect the answer]
    
    CONFIDENCE: [score 1-5, where 5 is highest confidence]
    </instructions>
    """
    
    response = chat(retrieval_prompt)
    return response

# Test with the same questions as before
print("Testing retrieval with refined memory structure...\n")

# Factual question
factual_question = "What is the relationship between AI and Machine Learning?"
factual_response = enhanced_retrieve_from_memory(factual_question, refined_memory, chat)
print(f"\nQuestion: {factual_question}")
print(format_llm_response(factual_response))

# Comparative question
comparative_question = "How does the definition of Machine Learning in Wikidata compare to modern understanding?"
comparative_response = enhanced_retrieve_from_memory(comparative_question, refined_memory, chat)
print(f"\nQuestion: {comparative_question}")
print(format_llm_response(comparative_response))

# Synthesis question
synthesis_question = "Based on our exploration, what are the key mathematical foundations of AI?"
synthesis_response = enhanced_retrieve_from_memory(synthesis_question, refined_memory, chat)
print(f"\nQuestion: {synthesis_question}")
print(format_llm_response(synthesis_response))
# Out:
# Testing retrieval with refined memory structure...
#
#
# Question: What is the relationship between AI and Machine Learning?
# # RELEVANT ENTITIES:
# - http://www.wikidata.org/entity/Q11660 (Artificial Intelligence)
# - http://www.wikidata.org/entity/Q5514059 (Symbolic Artificial Intelligence, explored as Machine Learning)
# - http://msc2010.org/resources/MSC/2010/68Txx (Mathematics Subject Classification for AI)
#
# # RELEVANT RELATIONSHIPS:
# - Q11660 (AI) has_part Q5514059 (Symbolic AI/Machine Learning)
# - Q11660 (AI) mathematics_subject_classification 68Txx
#
# # RETRIEVED FACTS:
# - Entity Q5514059 is labeled as "symbolic artificial intelligence" but was explored as if it were "Machine Learning"
# - Q5514059 is described as "methods in artificial intelligence research that are based on high-level symbolic representations of problems, logic and search, dominant from the 1950s until the 1980s"
# - AI has a "has part" (P527) relationship with Q5514059
# ...

# %% [markdown]
# **AI Prompt**
#
# Ok. What do we think of the result of this experiment?

# %% [markdown]
# **AI Response**
#
# The results of our experiment with the refined memory structure show significant improvements in several key areas:
#
# 1. **Clearer Structure and Relationships**:
#    - The LLM now explicitly identifies relevant entities and relationships
#    - It clearly distinguishes between different types of information (entities vs. relationships vs. gaps)
#    - The structured format makes it easier to trace how the LLM arrived at its conclusions
#
# 2. **Enhanced Awareness of Knowledge Gaps**:
#    - The LLM directly acknowledges and incorporates the knowledge gaps we added
#    - It uses these gaps to qualify its answers appropriately
#    - The gaps are presented in a way that suggests clear next steps for exploration
#
# 3. **Improved Confidence Assessment**:
#    - The addition of confidence scores provides a quantitative measure of answer reliability
#    - The LLM justifies these scores based on the completeness of available information
#    - This helps prioritize which areas need further investigation
#
# 4. **More Precise Answers**:
#    - The answers are more focused and directly tied to specific evidence
#    - The LLM clearly separates facts from interpretations
#    - The relationship between entities is more explicitly stated
#
# 5. **Better Knowledge Organization**:
#    - The separation of entities, relationships, and gaps creates a more navigable knowledge structure
#    - The LLM can more easily identify connections between different pieces of information
#    - The standardized metadata makes retrieval more consistent
#
# The experiment demonstrates that a well-structured memory system significantly enhances an LLM's ability to retrieve, organize, and reason with linked data. The JSON-LD structure with explicit relationships and knowledge gaps provides a more robust foundation for knowledge work than a flat or loosely structured approach.
#
# Would you like to further refine our memory structure or explore additional aspects of the linked data agent design?
